# %% [markdown]
# # **Equipo 2**
# ## **Proyecto: Cancer de mama en México**
#
# #### Integrantes:
# - Zoé Ariel García Martínez
# - Atenea De La Cruz Brito
# - Juan Luis Carrillo de la Cruz

# %% [markdown]
# ## **Pregunta de investigación 1**
#
# #### **¿Cómo ha sido el crecimiento en la incidencia del cáncer de mama en México?**

# %% [markdown]
# ### Analizo las bd que obtuve del SICAM.
# ### Comenzaré con el dataset (DS) correspondiente a los datos del 2013.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn  as sns
import folium
import geopandas as gpd
sns.set(style='whitegrid')

# %%
d_sicam13 = pd.read_csv("../Equipo_2_P2_Analisis/DATA/SICAM_DATA/Mastografias 2013.csv", encoding = 'latin-1', header = 1)
d_sicam13.head()
# Out:
#    Clave Entidad         Entidad  Clave Jurisdicción    Jurisdicción  \
# 0              1  Aguascalientes                   1  Aguascalientes
# 1              1  Aguascalientes                   1  Aguascalientes
# 2              1  Aguascalientes                   1  Aguascalientes
# 3              1  Aguascalientes                   1  Aguascalientes
# 4              1  Aguascalientes                   1  Aguascalientes
#
#    Clave Municipio       Municipio  Edad         Fecha Toma Masto  \
# 0                1  AGUASCALIENTES    52  2013-02-18 00:00:00.000
# 1                1  AGUASCALIENTES    48  2013-02-05 00:00:00.000
# 2                1  AGUASCALIENTES    48  2013-02-05 00:00:00.000
# 3                1  AGUASCALIENTES    69  2013-02-05 00:00:00.000
# 4                1  AGUASCALIENTES    44  2013-02-05 00:00:00.000
#
#   Fecha Interpretación Masto              Resultado
# 0    2013-02-18 00:00:00.000  Probablemente Benigna
# 1    2013-02-05 00:00:00.000               Negativa
# 2    2013-02-05 00:00:00.000               Negativa
# 3    2013-02-05 00:00:00.000               Negativa
# 4    2013-02-05 00:00:00.000               Negativa

# %% [markdown]
# ### reviso los types en mi DS:

# %%
d_sicam13.dtypes
# Out:
# Clave Entidad                  int64
# Entidad                       object
# Clave Jurisdicción             int64
# Jurisdicción                  object
# Clave Municipio                int64
# Municipio                     object
# Edad                           int64
# Fecha Toma Masto              object
# Fecha Interpretación Masto    object
# Resultado                     object
# dtype: object

# %% [markdown]
# ### reviso la info en mi DS

# %%
d_sicam13.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 790064 entries, 0 to 790063
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Clave Entidad               790064 non-null  int64
#  1   Entidad                     790064 non-null  object
#  2   Clave Jurisdicción          790064 non-null  int64
#  3   Jurisdicción                790064 non-null  object
#  4   Clave Municipio             790064 non-null  int64
#  5   Municipio                   790064 non-null  object
#  6   Edad                        790064 non-null  int64
#  7   Fecha Toma Masto            790064 non-null  object
#  8   Fecha Interpretación Masto  790064 non-null  object
#  9   Resultado                   790051 non-null  object
# dtypes: int64(4), object(6)
# memory usage: 60.3+ MB

# %%
# Se eliminan algunas columnas no necesarias 
columnas  = ['Clave Entidad', 'Clave Jurisdicción', 'Jurisdicción', 'Clave Municipio', 'Municipio']

d_sicam13 = d_sicam13.drop(columns = columnas)
d_sicam13.head()
# Out:
#           Entidad  Edad         Fecha Toma Masto Fecha Interpretación Masto  \
# 0  Aguascalientes    52  2013-02-18 00:00:00.000    2013-02-18 00:00:00.000
# 1  Aguascalientes    48  2013-02-05 00:00:00.000    2013-02-05 00:00:00.000
# 2  Aguascalientes    48  2013-02-05 00:00:00.000    2013-02-05 00:00:00.000
# 3  Aguascalientes    69  2013-02-05 00:00:00.000    2013-02-05 00:00:00.000
# 4  Aguascalientes    44  2013-02-05 00:00:00.000    2013-02-05 00:00:00.000
#
#                Resultado
# 0  Probablemente Benigna
# 1               Negativa
# 2               Negativa
# 3               Negativa
# 4               Negativa

# %% [markdown]
# ### algo que me gustaría hacer a mi DS es renombrar algunas columnas como ```Fecha Toma Masto``` y ```Fecha Interpretación Masto```, entonces procedo haciendo un remapeo con un diccionario y usando el método ```.rename()```:

# %%
c_rename = {
    'Fecha Interpretación Masto': 'fecha_interpretacion_masto',
    'Fecha Toma Masto': 'fecha_toma_masto',
    'Edad': 'edad',
    'Entidad': 'estado',
    'Resultado': 'resultado'
}

d_sicam13 = d_sicam13.rename(columns = c_rename)

d_sicam13.head()
# Out:
#            estado  edad         fecha_toma_masto fecha_interpretacion_masto  \
# 0  Aguascalientes    52  2013-02-18 00:00:00.000    2013-02-18 00:00:00.000
# 1  Aguascalientes    48  2013-02-05 00:00:00.000    2013-02-05 00:00:00.000
# 2  Aguascalientes    48  2013-02-05 00:00:00.000    2013-02-05 00:00:00.000
# 3  Aguascalientes    69  2013-02-05 00:00:00.000    2013-02-05 00:00:00.000
# 4  Aguascalientes    44  2013-02-05 00:00:00.000    2013-02-05 00:00:00.000
#
#                resultado
# 0  Probablemente Benigna
# 1               Negativa
# 2               Negativa
# 3               Negativa
# 4               Negativa

# %%
#ahora checo los tipos de datos disponibles: 

d_sicam13.dtypes
# Out:
# estado                        object
# edad                           int64
# fecha_toma_masto              object
# fecha_interpretacion_masto    object
# resultado                     object
# dtype: object

# %%
#ahora dropeo posibles NAN: 

d_sicam13 = d_sicam13.dropna()

# %%
#casteo los nuevos tipos de datos: 
dicc_conversion = {
    'estado': 'str',
    'fecha_toma_masto': 'datetime64[ms]',
    'fecha_interpretacion_masto': 'datetime64[ms]',
    'resultado': 'str'
}

d_sicam13 = d_sicam13.astype(dicc_conversion)

# %%
d_sicam13.head()
# Out:
#            estado  edad fecha_toma_masto fecha_interpretacion_masto  \
# 0  Aguascalientes    52       2013-02-18                 2013-02-18
# 1  Aguascalientes    48       2013-02-05                 2013-02-05
# 2  Aguascalientes    48       2013-02-05                 2013-02-05
# 3  Aguascalientes    69       2013-02-05                 2013-02-05
# 4  Aguascalientes    44       2013-02-05                 2013-02-05
#
#                resultado
# 0  Probablemente Benigna
# 1               Negativa
# 2               Negativa
# 3               Negativa
# 4               Negativa

# %%
#ahora agrupo por resultado de mastografía y estado:
d_sicam13_agrupada = d_sicam13.groupby(["resultado", "estado"])[["estado"]].agg("count")
d_sicam13_agrupada = d_sicam13_agrupada.rename(columns = {'estado': 'count'}).reset_index()
d_sicam13_agrupada.head()
# Out:
#                           resultado               estado  count
# 0  Altamente Sugestiva a Malignidad       Aguascalientes     31
# 1  Altamente Sugestiva a Malignidad      Baja California     31
# 2  Altamente Sugestiva a Malignidad  Baja California Sur      2
# 3  Altamente Sugestiva a Malignidad             Campeche     25
# 4  Altamente Sugestiva a Malignidad              Chiapas      1

# %% [markdown]
# Ya que la simple tabla no nos dice mucho al respecto, usaremos graficos de barras para poder observar que estados de la Republica Mexicana presentan una alta sugestiva a malignidad.

# %%
d_sicam13_agrupada = d_sicam13_agrupada.sort_values(by='count', ascending=False)

fig = plt.figure(figsize=(10,20))
ax = sns.barplot(x='count', y='estado', data=d_sicam13_agrupada, orient='h', hue='resultado') #dodge = false
ax.set_title('Grafica de resultados de mastografias del año 2013')
ax.set(xlabel='# de resultados', ylabel='Estado');

# %% [markdown]
# Como podemos observar la mayoria de los resultados arrojan un resultado negativo o con un tumor benigno, pero veamos como se comportan los datos sin esos resultados

# %%
d_sicam13_agrupada = d_sicam13_agrupada[(d_sicam13_agrupada['resultado'] != 'Benigna') & (d_sicam13_agrupada['resultado'] != 'Negativa')]

fig = plt.figure(figsize=(10,20))
ax = sns.barplot(x='count', y='estado', data=d_sicam13_agrupada, orient='h', hue='resultado') #dodge = false
ax.set_title('Grafica de resultados de mastografias del año 2013')
ax.set(xlabel='# de resultados', ylabel='Estado');

# %% [markdown]
# Los datos de nuevo nos presentan una baja incidencia de casos con respecto a la evaluacion adicional y la probabilidad de un tumor benigno, entonces, reduciremos nuestros datos unicamente a aquellos que se presentan como tumores con alta sugestiva a malignidad o anormalidades sospechosas.

# %%
d_sicam13_agrupada = d_sicam13_agrupada[(d_sicam13_agrupada['resultado'] != 'Probablemente Benigna') 
                                          & (d_sicam13_agrupada['resultado'] != 'Evaluación Adicional')]

fig = plt.figure(figsize=(10,20))
ax = sns.barplot(x='count', y='estado', data=d_sicam13_agrupada, orient='h', hue='resultado') #dodge = false
ax.set_title('Grafica de resultados de mastografias del año 2013')
plt.legend(loc='lower right')
ax.set(xlabel='# de resultados', ylabel='Estado');

# %% [markdown]
# ### Así, vemos que la entidad donde se han encontrado más tumores benignos es el Estado de México en el 2013

# %% [markdown]
# ### Ahora procederé a hacer el análogo con los demás datasets del SICAM.

# %%
#ahora agrupo por resultado de mastografía y estado:
d_sicam14 = pd.read_csv("../Equipo_2_P2_Analisis/DATA/SICAM_DATA/Mastografias 2014.csv", encoding = 'latin-1', header = 1)
d_sicam14 = d_sicam14.drop(columns = columnas)

d_sicam14 = d_sicam14.rename(columns = c_rename)
d_sicam14 = d_sicam14.dropna()

d_sicam14_agrupada = d_sicam14.groupby(["resultado", "estado"])[["estado"]].agg("count")
d_sicam14_agrupada = d_sicam14_agrupada.rename(columns = {'estado': 'count'}).reset_index()
d_sicam14_agrupada.head()
# Out:
#                           resultado           estado  count
# 0  Altamente Sugestiva a Malignidad   Aguascalientes     36
# 1  Altamente Sugestiva a Malignidad  Baja California     14
# 2  Altamente Sugestiva a Malignidad         Campeche     36
# 3  Altamente Sugestiva a Malignidad          Chiapas      4
# 4  Altamente Sugestiva a Malignidad        Chihuahua     49

# %% [markdown]
# Ya que la simple tabla no nos dice mucho al respecto, usaremos graficos de barras para poder observar que estados de la Republica Mexicana presentan una alta sugestiva a malignidad.

# %%
d_sicam14_agrupada = d_sicam14_agrupada.sort_values(by='count', ascending=False)

fig = plt.figure(figsize=(10,20))
ax = sns.barplot(x='count', y='estado', data=d_sicam14_agrupada, orient='h', hue='resultado') #dodge = false
ax.set_title('Grafica de resultados de mastografias del año 2014')
plt.legend(loc='lower right')
ax.set(xlabel='# de resultados', ylabel='Estado');

# %% [markdown]
# Como podemos observar la mayoria de los resultados arrojan un resultado negativo o con un tumor benigno, pero veamos como se comportan los datos sin esos resultados

# %%
d_sicam14_agrupada = d_sicam14_agrupada[(d_sicam14_agrupada['resultado'] != 'Benigna') 
                                        & (d_sicam14_agrupada['resultado'] != 'Negativa')]

fig = plt.figure(figsize=(10,20))
ax = sns.barplot(x='count', y='estado', data=d_sicam14_agrupada, orient='h', hue='resultado') #dodge = false
ax.set_title('Grafica de resultados de mastografias del año 2014')
plt.legend(loc='lower right')
ax.set(xlabel='# de resultados', ylabel='Estado');

# %% [markdown]
# Los datos de nuevo nos presentan una baja incidencia de casos con respecto a la evaluacion adicional y la probabilidad de un tumor benigno, entonces, reduciremos nuestros datos unicamente a aquellos que se presentan como tumores con alta sugestiva a malignidad o anormalidades sospechosas.

# %%
d_sicam14_agrupada = d_sicam14_agrupada[(d_sicam14_agrupada['resultado'] != 'Probablemente Benigna') 
                                          & (d_sicam14_agrupada['resultado'] != 'Evaluación Adicional')]

fig = plt.figure(figsize=(10,20))
ax = sns.barplot(x='count', y='estado', data=d_sicam14_agrupada, orient='h', hue='resultado') #dodge = false
ax.set_title('Grafica de resultados de mastografias del año 2014')
plt.legend(loc='lower right')
ax.set(xlabel='# de resultados', ylabel='Estado');

# %% [markdown]
# En el 2014 se observa claramente que el cancér es mucho más común en el EDOMEX

# %%
#ahora agrupo por resultado de mastografía y estado:
d_sicam15 = pd.read_csv("../Equipo_2_P2_Analisis/DATA/SICAM_DATA/Mastografias 2015.csv", 
                        encoding = 'latin-1', header = 1, low_memory=False)
d_sicam15 = d_sicam15.drop(columns = columnas)

d_sicam15 = d_sicam15.rename(columns = c_rename)
d_sicam15 = d_sicam15.dropna()

d_sicam15_agrupada = d_sicam15.groupby(["resultado", "estado"])[["estado"]].agg("count")
d_sicam15_agrupada = d_sicam15_agrupada.rename(columns = {'estado': 'count'}).reset_index()
d_sicam15_agrupada.head()
# Out:
#                           resultado               estado  count
# 0  Altamente Sugestiva a Malignidad       Aguascalientes     54
# 1  Altamente Sugestiva a Malignidad      Baja California     15
# 2  Altamente Sugestiva a Malignidad  Baja California Sur      3
# 3  Altamente Sugestiva a Malignidad             Campeche     24
# 4  Altamente Sugestiva a Malignidad            Chihuahua     55

# %%
d_sicam15_agrupada = d_sicam15_agrupada.sort_values(by='count', ascending=False)

fig = plt.figure(figsize=(10,20))
ax = sns.barplot(x='count', y='estado', data=d_sicam15_agrupada, orient='h', hue='resultado') #dodge = false
ax.set_title('Grafica de resultados de mastografias del año 2015')
plt.legend(loc='lower right')
ax.set(xlabel='# de resultados', ylabel='Estado');

# %%
d_sicam15_agrupada = d_sicam15_agrupada[(d_sicam15_agrupada['resultado'] != 'Benigna') 
                                        & (d_sicam15_agrupada['resultado'] != 'Negativa')]

fig = plt.figure(figsize=(10,20))
ax = sns.barplot(x='count', y='estado', data=d_sicam15_agrupada, orient='h', hue='resultado') #dodge = false
ax.set_title('Grafica de resultados de mastografias del año 2015')
plt.legend(loc='lower right')
ax.set(xlabel='# de resultados', ylabel='Estado');

# %% [markdown]
# Los datos de nuevo nos presentan una baja incidencia de casos con respecto a la evaluacion adicional y la probabilidad de un tumor benigno, entonces, reduciremos nuestros datos unicamente a aquellos que se presentan como tumores con alta sugestiva a malignidad o anormalidades sospechosas.

# %%
d_sicam15_agrupada = d_sicam15_agrupada[(d_sicam15_agrupada['resultado'] != 'Probablemente Benigna') 
                                          & (d_sicam15_agrupada['resultado'] != 'Evaluación Adicional')]

fig = plt.figure(figsize=(10,20))
ax = sns.barplot(x='count', y='estado', data=d_sicam15_agrupada, orient='h', hue='resultado') #dodge = false
ax.set_title('Grafica de resultados de mastografias del año 2015')
plt.legend(loc='lower right')
ax.set(xlabel='# de resultados', ylabel='Estado');

# %% [markdown]
# En el 2015 es preocupante el aumento de casos altamente sugestivos a malignidad en el estado de Nuevo León, pues on respecto a los años anteriores el aumento fue de forma abrupta.

# %%
#ahora agrupo por resultado de mastografía y estado:
d_sicam16 = pd.read_csv("../Equipo_2_P2_Analisis/DATA/SICAM_DATA/Mastografias 2016.csv", 
                        encoding = 'latin-1', header = 1, low_memory=False)
d_sicam16 = d_sicam16.drop(columns = columnas)

d_sicam16 = d_sicam16.rename(columns = c_rename)
d_sicam16 = d_sicam16.dropna()

d_sicam16_agrupada = d_sicam16.groupby(["resultado", "estado"])[["estado"]].agg("count")
d_sicam16_agrupada = d_sicam16_agrupada.rename(columns = {'estado': 'count'}).reset_index()
d_sicam16_agrupada.head()
# Out:
#                           resultado               estado  count
# 0  Altamente Sugestiva a Malignidad       Aguascalientes     47
# 1  Altamente Sugestiva a Malignidad      Baja California     16
# 2  Altamente Sugestiva a Malignidad  Baja California Sur      3
# 3  Altamente Sugestiva a Malignidad             Campeche     20
# 4  Altamente Sugestiva a Malignidad              Chiapas      5

# %%
d_sicam16_agrupada = d_sicam16_agrupada.sort_values(by='count', ascending=False)

fig = plt.figure(figsize=(10,20))
ax = sns.barplot(x='count', y='estado', data=d_sicam16_agrupada, orient='h', hue='resultado') #dodge = false
ax.set_title('Grafica de resultados de mastografias del año 2016')
plt.legend(loc='lower right')
ax.set(xlabel='# de resultados', ylabel='Estado');

# %%
d_sicam16_agrupada = d_sicam16_agrupada[(d_sicam16_agrupada['resultado'] != 'Benigna') 
                                        & (d_sicam16_agrupada['resultado'] != 'Negativa')]

fig = plt.figure(figsize=(10,20))
ax = sns.barplot(x='count', y='estado', data=d_sicam16_agrupada, orient='h', hue='resultado') #dodge = false
ax.set_title('Grafica de resultados de mastografias del año 2016')
plt.legend(loc='lower right')
ax.set(xlabel='# de resultados', ylabel='Estado');

# %%
d_sicam16_agrupada = d_sicam16_agrupada[(d_sicam16_agrupada['resultado'] != 'Probablemente Benigna') 
                                          & (d_sicam16_agrupada['resultado'] != 'Evaluación Adicional')]

fig = plt.figure(figsize=(10,20))
ax = sns.barplot(x='count', y='estado', data=d_sicam16_agrupada, orient='h', hue='resultado') #dodge = false
ax.set_title('Grafica de resultados de mastografias del año 2016')
plt.legend(loc='lower right')
ax.set(xlabel='# de resultados', ylabel='Estado');

# %% [markdown]
# En el 2016 presenta una incidencia mayor de nuevo en el EDOMEX.

# %%
#ahora agrupo por resultado de mastografía y estado:
d_sicam17 = pd.read_csv("../Equipo_2_P2_Analisis/DATA/SICAM_DATA/Mastografias 2017.csv", 
                        encoding = 'latin-1', header = 1, low_memory=False)
d_sicam17 = d_sicam17.drop(columns = columnas)

d_sicam17 = d_sicam17.rename(columns = c_rename)
d_sicam17 = d_sicam17.dropna()

d_sicam17_agrupada = d_sicam17.groupby(["resultado", "estado"])[["estado"]].agg("count")
d_sicam17_agrupada = d_sicam17_agrupada.rename(columns = {'estado': 'count'}).reset_index()
d_sicam17_agrupada.head()
# Out:
#                           resultado               estado  count
# 0  Altamente Sugestiva a Malignidad       Aguascalientes     22
# 1  Altamente Sugestiva a Malignidad      Baja California     22
# 2  Altamente Sugestiva a Malignidad  Baja California Sur      6
# 3  Altamente Sugestiva a Malignidad             Campeche     12
# 4  Altamente Sugestiva a Malignidad              Chiapas     10

# %%
d_sicam17_agrupada = d_sicam17_agrupada.sort_values(by='count', ascending=False)

fig = plt.figure(figsize=(10,20))
ax = sns.barplot(x='count', y='estado', data=d_sicam17_agrupada, orient='h', hue='resultado') #dodge = false
ax.set_title('Grafica de resultados de mastografias del año 2017')
plt.legend(loc='lower right')
ax.set(xlabel='# de resultados', ylabel='Estado');

# %%
d_sicam17_agrupada = d_sicam17_agrupada[(d_sicam17_agrupada['resultado'] != 'Benigna') 
                                        & (d_sicam17_agrupada['resultado'] != 'Negativa')]

fig = plt.figure(figsize=(10,20))
ax = sns.barplot(x='count', y='estado', data=d_sicam17_agrupada, orient='h', hue='resultado') #dodge = false
ax.set_title('Grafica de resultados de mastografias del año 2017')
plt.legend(loc='lower right')
ax.set(xlabel='# de resultados', ylabel='Estado');

# %%
d_sicam17_agrupada = d_sicam17_agrupada[(d_sicam17_agrupada['resultado'] != 'Probablemente Benigna') 
                                          & (d_sicam17_agrupada['resultado'] != 'Evaluación Adicional')]

fig = plt.figure(figsize=(10,20))
ax = sns.barplot(x='count', y='estado', data=d_sicam17_agrupada, orient='h', hue='resultado') #dodge = false
ax.set_title('Grafica de resultados de mastografias del año 2017')
plt.legend(loc='lower right')
ax.set(xlabel='# de resultados', ylabel='Estado');

# %% [markdown]
# En el 2017 la CDMX tuvo el mayor numero de resultados altamente sugestivos a malignidad, mientras que el EDOMEX vuelve a encabezar en anormalidad sospechosa

# %%
#ahora agrupo por resultado de mastografía y estado:
d_sicam19 = pd.read_csv("../Equipo_2_P2_Analisis/DATA/SICAM_DATA/Mastografias 2019.csv", 
                        encoding = 'latin-1', header = 1, low_memory=False)
d_sicam19 = d_sicam19.drop(columns = columnas)

d_sicam19 = d_sicam19.rename(columns = c_rename)
d_sicam19 = d_sicam19.dropna()

d_sicam19_agrupada = d_sicam19.groupby(["resultado", "estado"])[["estado"]].agg("count")
d_sicam19_agrupada = d_sicam19_agrupada.rename(columns = {'estado': 'count'}).reset_index()
d_sicam19_agrupada.head()
# Out:
#                           resultado               estado  count
# 0  Altamente Sugestiva a Malignidad       Aguascalientes     21
# 1  Altamente Sugestiva a Malignidad      Baja California     29
# 2  Altamente Sugestiva a Malignidad  Baja California Sur     12
# 3  Altamente Sugestiva a Malignidad             Campeche      1
# 4  Altamente Sugestiva a Malignidad              Chiapas     21

# %%
d_sicam19_agrupada = d_sicam19_agrupada.sort_values(by='count', ascending=False)

fig = plt.figure(figsize=(10,20))
ax = sns.barplot(x='count', y='estado', data=d_sicam19_agrupada, orient='h', hue='resultado') #dodge = false
ax.set_title('Grafica de resultados de mastografias del año 2019')
plt.legend(loc='lower right')
ax.set(xlabel='# de resultados', ylabel='Estado');

# %%
d_sicam19_agrupada = d_sicam19_agrupada[(d_sicam19_agrupada['resultado'] != 'Benigna') 
                                        & (d_sicam19_agrupada['resultado'] != 'Negativa')]

fig = plt.figure(figsize=(10,20))
ax = sns.barplot(x='count', y='estado', data=d_sicam19_agrupada, orient='h', hue='resultado') #dodge = false
ax.set_title('Grafica de resultados de mastografias del año 2019')
plt.legend(loc='lower right')
ax.set(xlabel='# de resultados', ylabel='Estado');

# %%
d_sicam19_agrupada = d_sicam19_agrupada[(d_sicam19_agrupada['resultado'] != 'Probablemente Benigna') 
                                          & (d_sicam19_agrupada['resultado'] != 'Evaluación Adicional')]

fig = plt.figure(figsize=(10,20))
ax = sns.barplot(x='count', y='estado', data=d_sicam19_agrupada, orient='h', hue='resultado') #dodge = false
ax.set_title('Grafica de resultados de mastografias del año 2019')
plt.legend(loc='lower right')
ax.set(xlabel='# de resultados', ylabel='Estado');

# %% [markdown]
# En el 2019 el EDOMEX vuelve a encabezar en anormalidad sospechosa, pero para este año Michoacan supero a la CDMX en anormalidades sospechosas

# %% [markdown]
# ### ahora veamos el conteo con respecto al tiempo:

# %%
conteo = {'Año': list(range(2013, 2020)), 
          'Numero de pruebas': [d_sicam13.count()[0], d_sicam14.count()[0], d_sicam15.count()[0], 
                                d_sicam16.count()[0], d_sicam17.count()[0], np.nan, d_sicam19.count()[0]]}
conteo = pd.DataFrame(conteo)


fig = plt.figure(figsize=(12,7))
ax = sns.barplot(x='Año', y='Numero de pruebas', data=conteo)
ax.set_title('Total de pruebas realizadas por año')
ax.set(ylabel='Total de mastografias');

# %% [markdown]
# Podemos observar claramente que en el 2018 no se tienen datos pues la liga de descarga se encontraba caida, además podemos observar que en el 2015 y el 2016 fueron los años con mayor numeros de mastografias. Seria bueno preguntarse el porque el numero se ha reducido en lugar de aumentar...

# %% [markdown]
# ## Juntar los datasets
# Se realizara un dataset enorme para pooder obtener graficos de a cuerdo a la edad, entidad federativa, mastografia y resltado

# %%
masto = d_sicam13.append([d_sicam14, d_sicam15, d_sicam16, d_sicam17, d_sicam19]).reset_index(drop=True)
masto.tail()
# Out:
#             estado  edad fecha_toma_masto fecha_interpretacion_masto  \
# 5052603  Zacatecas  55.0       13/11/2019                 20/11/2019
# 5052604  Zacatecas  62.0       13/11/2019                 20/11/2019
# 5052605  Zacatecas  60.0       13/11/2019                 20/11/2019
# 5052606  Zacatecas  59.0       13/11/2019                 20/11/2019
# 5052607  Zacatecas  43.0       13/11/2019                 30/11/2019
#
#                     resultado
# 5052603  Evaluación Adicional
# 5052604               Benigna
# 5052605  Evaluación Adicional
# 5052606               Benigna
# 5052607  Evaluación Adicional

# %%
fig = plt.figure(figsize=(15,15))
ax = sns.histplot(data=masto, x="edad", hue='resultado', binwidth=3, multiple='stack')
ax.set(title='Edades de personas con estudios de mastografia entre 2013 y 2019', xlabel='edad', ylabel='conteo');

# %%
# ahora analizaremos los datos donde tenemos sospechas, que se encuentran un poco
# ocultos por los beningnos y positivos

masto_malig = masto[(masto['resultado'] != 'Negativa') & (masto['resultado'] !='Evaluación Adicional')
     & (masto['resultado'] != 'Benigna') & (masto['resultado'] != 'Probablemente Benigna')]

# %%
fig = plt.figure(figsize=(15,15))
ax = sns.histplot(data=masto_malig, x="edad", hue='resultado', binwidth=3, multiple='stack')
ax.set(title='Edades de personas con estudios de mastografia entre 2013 y 2019', 
       xlabel='edad', ylabel='conteo');

# %%
masto_group = masto.groupby(["resultado", "estado"])[["estado"]].agg("count")
masto_group = masto_group.rename(columns = {'estado': 'count'}).reset_index()
masto_group.head(2)
# Out:
#                           resultado           estado  count
# 0  Altamente Sugestiva a Malignidad   Aguascalientes    211
# 1  Altamente Sugestiva a Malignidad  Baja California    127

# %%
masto_group_agre = masto_group[masto_group['resultado'] == 'Altamente Sugestiva a Malignidad']
masto_group_agre = masto_group_agre.sort_values(by='count', ascending=False)

masto_group_beni = masto_group[masto_group['resultado'] == 'Benigna']
masto_group_beni = masto_group_beni.sort_values(by='count', ascending=False)

fig, axes = plt.subplots(1, 2, sharex=False, figsize=(15,10))
fig.suptitle('Graficos de mastografias')
fig.tight_layout(pad=9)
sns.barplot(x='count', y='estado', data=masto_group_agre, orient='h', palette="Blues_d", ax=axes[0])
axes[0].set_title('Grafica de tumores altamente sugestivos a malignidad')
axes[0].set(xlabel='# de resultados', ylabel='Estado')
axes[0].locator_params(axis='x', nbins=10)
sns.barplot(x='count', y='estado', data=masto_group_beni, orient='h', palette="Blues_d", ax=axes[1])
axes[1].set_title('Grafica de tumores benignos')
axes[1].set(xlabel='# de resultados', ylabel='')
axes[1].locator_params(axis='x', nbins=5);

# %% [markdown]
# Del 2013 al 2019 podemos observar que los estados más afectados por el cáncer son:
# * Nuevo León
# * Estado de México
# * Ciudad de México
#
# La diference que hay entre Tamaulipas y Ciudad de México es de varios cientos de tumores altamente sugestivos a malignidad. Por lo que los estados mencionados anteriormente presentan una más alta suceptibilidad a estos resultados, sin embargo, para poder concluir esto es necesario analizar su densidad poblacional, que claramente, también mayor en estos estados.
#
#
# A continuación se presenta el mapa donde podemos observar que estados estan más afectados por tumores altamente sugestivos a malignidad.

# %%
mexico = '../Equipo_2_P2_Analisis/DATA/mexico.json'
fname = mexico
mxn = gpd.read_file(fname)
mxn = mxn[1:][['name', 'geometry']]
mxn = mxn.rename(columns= {'name': 'estado'})
mxn
# Out:
#                  estado                                           geometry
# 1       Baja California  MULTIPOLYGON (((-114.14750 28.00015, -114.2070...
# 2   Baja California Sur  MULTIPOLYGON (((-109.79843 24.15516, -109.8624...
# 3              Coahuila  POLYGON ((-99.80696 27.77142, -99.96720 27.640...
# 4             Chihuahua  POLYGON ((-106.50605 31.77026, -106.42895 31.7...
# 5               Durango  POLYGON ((-103.62726 26.64393, -103.32570 26.4...
# 6               Sinaloa  MULTIPOLYGON (((-108.88272 25.44318, -108.8188...
# 7                Sonora  MULTIPOLYGON (((-109.23137 26.26342, -109.2254...
# 8             Zacatecas  POLYGON ((-100.82844 24.56496, -100.86968 24.4...
# 9            Nuevo León  POLYGON ((-99.80696 27.77142, -99.74044 27.722...
# 10      San Luis Potosí  POLYGON ((-100.05727 23.24106, -100.08926 23.1...
# 11           Tamaulipas  POLYGON ((-97.13927 25.96583, -97.16747 25.828...
# 12       Aguascalientes  POLYGON ((-101.84543 22.01747, -101.89173 21.9...
# 13               Colima  MULTIPOLYGON (((-110.92431 18.72736, -110.9794...
# 14              Jalisco  POLYGON ((-102.76049 21.74880, -102.66138 21.7...
# 15            Michoacán  POLYGON ((-100.28599 20.21339, -100.23571 20.1...
# 16              Nayarit  MULTIPOLYGON (((-106.43706 21.49595, -106.3727...
# 17             Campeche  MULTIPOLYGON (((-91.52440 18.76659, -91.62084 ...
# 18               Oaxaca  POLYGON ((-98.55455 16.31828, -98.51943 16.350...
# 19               Puebla  POLYGON ((-96.72812 18.41025, -96.78951 18.283...
# 20              Tabasco  POLYGON ((-90.99090 17.80196, -90.99199 17.251...
# 21             Tlaxcala  POLYGON ((-98.64087 19.46191, -98.64749 19.513...
# 22     Distrito Federal  POLYGON ((-98.96395 19.08912, -99.01780 19.086...
# 23           Guanajuato  POLYGON ((-99.79062 21.41911, -99.79253 21.291...
# 24             Guerrero  POLYGON ((-99.49550 18.67405, -99.50738 18.624...
# 25              Hidalgo  POLYGON ((-98.00019 20.48449, -98.05248 20.427...
# 26               México  POLYGON ((-98.65948 19.58552, -98.70909 19.582...
# 27              Morelos  POLYGON ((-98.96395 19.08912, -98.89326 19.072...
# 28            Querétaro  POLYGON ((-99.04338 21.26831, -99.04230 21.175...
# 29             Veracruz  POLYGON ((-97.78186 22.27335, -97.77135 22.131...
# 30              Chiapas  MULTIPOLYGON (((-93.97061 16.00979, -94.11486 ...
# 31         Quintana Roo  MULTIPOLYGON (((-86.74901 20.56769, -86.79711 ...
# 32              Yucatán  POLYGON ((-87.53801 21.49942, -87.52509 21.298...

# %%
renombre = {
    'Coahuila de Zaragoza': 'Coahuila',
    'Ciudad de México': 'Distrito Federal',
    'Michoacán de Ocampo': 'Michoacán',
    'Veracruz de Ignacio de la Llave': 'Veracruz',
    'Estado de México': 'México'
}
masto_group_agre = masto_group_agre.drop(columns='resultado').rename(columns={'count': 'agre_count'})
masto_group_agre = masto_group_agre.replace({"estado": renombre})
masto_group_beni = masto_group_beni.drop(columns='resultado').rename(columns={'count': 'beni_count'})
masto_group_beni = masto_group_beni.replace({"estado": renombre})
masto_group_agre = masto_group_agre.merge(masto_group_beni, on='estado')
masto_group_agre.head()
# Out:
#              estado  agre_count  beni_count
# 0        Nuevo León        1672       73776
# 1            México        1621      796965
# 2  Distrito Federal         897      414337
# 3        Tamaulipas         513       87949
# 4           Jalisco         501      307813

# %%
masto_mxn = mxn.merge(masto_group_agre,on="estado")
masto_mxn
masto_mxn.head()
# Out:
#                 estado                                           geometry  \
# 0      Baja California  MULTIPOLYGON (((-114.14750 28.00015, -114.2070...
# 1  Baja California Sur  MULTIPOLYGON (((-109.79843 24.15516, -109.8624...
# 2             Coahuila  POLYGON ((-99.80696 27.77142, -99.96720 27.640...
# 3            Chihuahua  POLYGON ((-106.50605 31.77026, -106.42895 31.7...
# 4              Durango  POLYGON ((-103.62726 26.64393, -103.32570 26.4...
#
#    agre_count  beni_count
# 0         127       66889
# 1          26       19951
# 2         165       37631
# 3         313       66448
# 4         114       56153

# %%
mymap =  folium.Map(location=[25, -100], zoom_start=4.5, width="100%", height='100%')
myscale = (masto_mxn['agre_count'].quantile((0,0.1,0.75,0.9,0.98,1))).tolist()
myscale2 = (masto_mxn['beni_count'].quantile((0,0.1,0.75,0.9,0.98,1))).tolist()


folium.Choropleth(
    geo_data=masto_mxn,
    name='Agre',
     data=masto_mxn,
     columns=['estado','agre_count'],
     key_on="feature.properties.estado",
     fill_color='YlGnBu',
     threshold_scale=myscale,
     fill_opacity=1,
     line_opacity=0.2,
     legend_name='Tumores altamente sugestivos a malignidad',
     smooth_factor=0
).add_to(mymap)

folium.Choropleth(
    geo_data=masto_mxn,
    name='Beni',
     data=masto_mxn,
     columns=['estado','beni_count'],
     key_on="feature.properties.estado",
     fill_color='YlGnBu',
     threshold_scale=myscale2,
     fill_opacity=1,
     line_opacity=0.2,
     legend_name='Tumores benignos',
     smooth_factor=0
).add_to(mymap)

style_function = lambda x: {'fillColor': '#ffffff', 
                            'color':'#000000', 
                            'fillOpacity': 0.1, 
                            'weight': 0.1}
highlight_function = lambda x: {'fillColor': '#000000', 
                                'color':'#000000', 
                                'fillOpacity': 0.50, 
                                'weight': 0.1}
MXN = folium.features.GeoJson(
    masto_mxn,
    style_function=style_function, 
    control=False,
    highlight_function=highlight_function, 
    tooltip=folium.features.GeoJsonTooltip(
        fields=['estado','agre_count'],
        aliases=['Estado: ','Tumores altamente sugestivos a malignidad: '],
        style=("background-color: white; color: #333333; font-family: arial; font-size: 12px; padding: 10px;") 
    )
)

MXN2 = folium.features.GeoJson(
    masto_mxn,
    style_function=style_function, 
    control=False,
    highlight_function=highlight_function, 
    tooltip=folium.features.GeoJsonTooltip(
        fields=['estado','beni_count'],
        aliases=['Estado: ','Tumores benignos: '],
        style=("background-color: white; color: #333333; font-family: arial; font-size: 12px; padding: 10px;") 
    )
)
mymap.add_child(MXN)
mymap.add_child(MXN2)
# mymap.keep_in_front(MXN)
# mymap.keep_in_front(MXN2)
folium.LayerControl(collapsed=False).add_to(mymap)
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_58a788224e0b4d70a4eda231be969b50%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js%22%3E%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20.foliumtooltip%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20background-color%3A%20white%3B%20color%3A%20%23333333%3B%20font-family%3A%20arial%3B%20font-size%3A%2012px%3B%20padding%3A%2010px%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20.foliumtooltip%20ta ...

# %% [markdown]
# ### Ahora, se analiza el siguiente dataset contenido en pdf:

# %% [markdown]
# ##### Mientras buscaba los datos de mortabilidad asociados al cancer de mama, pude darme cuenta que solo habían datos accesibles en formato ```pdf``` por esta razón, tuve que transformar los datos a ```csv```, para esto usé la paquetería ```tabula``` y realicé una función para automatizar la transformación de los archivos correspondientes:

# %%
#imoporto la librería y hago una prueba con un archivo:
from tabula import convert_into
convert_into("d:/Equipo_2_P2/DATA/Morbilidad_2013_2019/pdf/morbilidad_2013.pdf", 
             "d:/Equipo_2_P2/DATA/Morbilidad_2013_2019/csv/test.csv", output_format="csv")
# Out:
# 'pages' argument isn't specified.Will extract only from page 1 by default.

# %%
#defino mi transformador
def transformador(file, salida): 
    d = convert_into(file, salida, output_format = 'csv')
    return d

# %%
#creo listas con los nombres de los archivos correspondientes: 
lista_pdf = []
lista_csv = []
for i in range(3, 10):
    lista_pdf.append(f"d:/Equipo_2_P2/DATA/Morbilidad_2013_2019/pdf/morbilidad_201{i}.pdf")
    lista_csv.append(f"d:/Equipo_2_P2/DATA/Morbilidad_2013_2019/csv/morbilidad_201{i}.csv")
    
print(lista_pdf, '\n', lista_csv)
# Out:
# ['d:/Equipo_2_P2/DATA/Morbilidad_2013_2019/pdf/morbilidad_2013.pdf', 'd:/Equipo_2_P2/DATA/Morbilidad_2013_2019/pdf/morbilidad_2014.pdf', 'd:/Equipo_2_P2/DATA/Morbilidad_2013_2019/pdf/morbilidad_2015.pdf', 'd:/Equipo_2_P2/DATA/Morbilidad_2013_2019/pdf/morbilidad_2016.pdf', 'd:/Equipo_2_P2/DATA/Morbilidad_2013_2019/pdf/morbilidad_2017.pdf', 'd:/Equipo_2_P2/DATA/Morbilidad_2013_2019/pdf/morbilidad_2018.pdf', 'd:/Equipo_2_P2/DATA/Morbilidad_2013_2019/pdf/morbilidad_2019.pdf']
#  ['d:/Equipo_2_P2/DATA/Morbilidad_2013_2019/csv/morbilidad_2013.csv', 'd:/Equipo_2_P2/DATA/Morbilidad_2013_2019/csv/morbilidad_2014.csv', 'd:/Equipo_2_P2/DATA/Morbilidad_2013_2019/csv/morbilidad_2015.csv', 'd:/Equipo_2_P2/DATA/Morbilidad_2013_2019/csv/morbilidad_2016.csv', 'd:/Equipo_2_P2/DATA/Morbilidad_2013_2019/csv/morbilidad_2017.csv', 'd:/Equipo_2_P2/DATA/Morbilidad_2013_2019/csv/morbilidad_2018.csv', 'd:/Equipo_2_P2/DATA/Morbilidad_2013_2019/csv/morbilidad_2019.csv']

# %%
#transformo en el rango de mis listas
for i in range(0,len(lista_pdf)):
    transformador(lista_pdf[i], lista_csv[i])
# Out:
# 'pages' argument isn't specified.Will extract only from page 1 by default.
# 'pages' argument isn't specified.Will extract only from page 1 by default.
# 'pages' argument isn't specified.Will extract only from page 1 by default.
# 'pages' argument isn't specified.Will extract only from page 1 by default.
# 'pages' argument isn't specified.Will extract only from page 1 by default.
# 'pages' argument isn't specified.Will extract only from page 1 by default.
# 'pages' argument isn't specified.Will extract only from page 1 by default.

# %% [markdown]
# Datos disponibles en la fuente: SALUD, Dirección General de Epidemiología (DGE). (2020). Anuarios de Morbilidad 1984-2019. Disponible en: https://epidemiologia.salud.gob.mx/anuario/html/incidencia_enfermedad.html

# %%
# ahora procedo a realizar una limpieza de las mismas: 

morbilidad_13 = pd.read_csv('d:/Equipo_2_P2/DATA/Morbilidad_2013_2019/csv/morbilidad_2013.csv', 
                            encoding = 'latin-1', header = 2)
morbilidad_13.head()
# Out:
#             Unnamed: 0  < 1  1 - 4  5 - 9  10 - 14  15 - 19  20 - 24  25 - 44  \
# 0       Aguascalientes  0.0    0.0    0.0      0.0     0.00     3.43    21.42
# 1      Baja California  0.0    0.0    0.0      0.0     0.00     1.32    18.43
# 2  Baja California Sur  0.0    0.0    0.0      0.0     3.17     0.00    13.87
# 3             Campeche  0.0    0.0    0.0      0.0     0.00     0.00    58.10
# 4             Coahuila  0.0    0.0    0.0      0.0     0.00     1.61     6.54
#
#    45 - 49  50 - 59  60 - 64  65 y +  Unnamed: 12
# 0   110.68   108.21   164.13  115.95        33.04
# 1    31.21    71.43    80.61   73.56        20.17
# 2    74.44    76.53    54.70   52.92        19.30
# 3   264.16   258.38   342.79  191.92        76.25
# 4    30.81    54.43    15.60   44.62        12.27

# %% [markdown]
# #### como podemos ver este DS no tiene muchos inconvenientes, pues aunque presenta valores nulos 0, estos sí son representativos de las muestras, es decir que tienen significado.
# #### el único problema verdadero es que dos columnas no tienen nombre, entonces se procede a nombrar:

# %%
dicc_nombre = {
    'Unnamed: 0': 'estado',
    'Unnamed: 12': 'incidencia'
}

morbilidad_13 = morbilidad_13.rename(columns = dicc_nombre)

morbilidad_13.head()
# Out:
#                 estado  < 1  1 - 4  5 - 9  10 - 14  15 - 19  20 - 24  25 - 44  \
# 0       Aguascalientes  0.0    0.0    0.0      0.0     0.00     3.43    21.42
# 1      Baja California  0.0    0.0    0.0      0.0     0.00     1.32    18.43
# 2  Baja California Sur  0.0    0.0    0.0      0.0     3.17     0.00    13.87
# 3             Campeche  0.0    0.0    0.0      0.0     0.00     0.00    58.10
# 4             Coahuila  0.0    0.0    0.0      0.0     0.00     1.61     6.54
#
#    45 - 49  50 - 59  60 - 64  65 y +  incidencia
# 0   110.68   108.21   164.13  115.95       33.04
# 1    31.21    71.43    80.61   73.56       20.17
# 2    74.44    76.53    54.70   52.92       19.30
# 3   264.16   258.38   342.79  191.92       76.25
# 4    30.81    54.43    15.60   44.62       12.27

# %% [markdown]
# #### además de esto ahora voy a indexar comenzando por el estado que tiene la incidencia más alta:

# %%
morbilidad_13 = morbilidad_13.sort_values(by="incidencia",ascending =False).reset_index(drop = True)
morbilidad_13.head(5)
# Out:
#             estado  < 1  1 - 4  5 - 9  10 - 14  15 - 19  20 - 24  25 - 44  \
# 0         Campeche  0.0    0.0    0.0     0.00     0.00     0.00    58.10
# 1   Aguascalientes  0.0    0.0    0.0     0.00     0.00     3.43    21.42
# 2          Jalisco  0.0    0.0    0.0     0.28     1.12     1.99    27.16
# 3         Veracruz  0.0    0.0    0.0     0.00     2.68     5.67    25.41
# 4  San Luis Potosí  0.0    0.0    0.0     0.00     0.00     0.81    28.29
#
#    45 - 49  50 - 59  60 - 64  65 y +  incidencia
# 0   264.16   258.38   342.79  191.92       76.25
# 1   110.68   108.21   164.13  115.95       33.04
# 2   110.88    89.91   141.10   72.41       32.39
# 3    69.23    90.19    96.98   66.66       29.85
# 4    88.65   103.23   101.62   46.06       28.31

# %%
fig = plt.figure(figsize=(15,15))
ax = sns.histplot(data=morbilidad_13, x="incidencia")
ax.set(title='Edades de personas con estudios de mastografia entre 2013 y 2019', 
       xlabel='edad', ylabel='conteo');

# %% [markdown]
# ### Ahora hago lo mismo para los demás DS

# %%
morbilidad_14 = pd.read_csv('d:/Equipo_2_P2/DATA/Morbilidad_2013_2019/csv/morbilidad_2014.csv', 
                            encoding = 'latin-1', header = 2)
morbilidad_14 = morbilidad_14.rename(columns = dicc_nombre)
morbilidad_14 = morbilidad_14.sort_values(by="incidencia",ascending =False).reset_index(drop = True)

# como me encontré unos "N.A" dentro de algunas columnas las limpie usando .to_numeric,
# exceptuando la primer fila, que es la de los estados
for elemento in range(0, len(list(morbilidad_14))):
    if elemento != 0:
        morbilidad_14.iloc[:, elemento] = pd.to_numeric(morbilidad_14.iloc[: ,elemento], 
                                                        errors = 'coerce').fillna(value = 0)

# morbilidad_14['estado'] = estado
morbilidad_14.head(5)
# Out:
#             estado  < 1  1 - 4  5 - 9  10 - 14  15 - 19  20 - 24  25 - 44  \
# 0         Campeche  0.0    0.0    0.0     2.53     0.00     2.40    50.81
# 1           Colima  0.0    0.0    0.0     0.00     0.00     9.40    36.25
# 2         Veracruz  0.0    0.0    0.0     0.56     0.27     5.35    38.21
# 3   Aguascalientes  0.0    0.0    0.0     0.00     0.00     3.38    39.13
# 4  San Luis Potosí  0.0    0.0    0.0     0.00     0.00     4.03    29.18
#
#    45 - 49  50 - 59  60 - 64  65 y +  incidencia
# 0   243.18   272.20   280.41  202.53       91.75
# 1   194.82   202.90   220.61  178.38       74.71
# 2   103.95   113.34   139.61   82.70       49.08
# 3    96.22   124.04   118.66  132.23       48.38
# 4    85.03   133.80   100.21   84.33       42.47

# %%
morbilidad_15 = pd.read_csv('d:/Equipo_2_P2/DATA/Morbilidad_2013_2019/csv/morbilidad_2015.csv', 
                            encoding = 'latin-1', header = 2)
morbilidad_15 = morbilidad_15.rename(columns = dicc_nombre)
morbilidad_15 = morbilidad_15.sort_values(by="incidencia",ascending =False).reset_index(drop = True)

# como me encontré unos "N.A" dentro de algunas columnas las limpie usando .to_numeric, 
# exceptuando la primer fila, que es la de los estados
for elemento in range(0, len(list(morbilidad_15))):
    if elemento != 0:
        morbilidad_15.iloc[:, elemento] = pd.to_numeric(morbilidad_15.iloc[: ,elemento], 
                                                        errors = 'coerce').fillna(value = 0)

# morbilidad_15['estado'] = estado
morbilidad_15.head(5)
# Out:
#            estado  < 1  1 - 4  5 - 9  10 - 14  15 - 19  20 - 24  25 - 44  \
# 0          Colima  0.0    0.0    0.0     0.00     0.00     6.25    46.84
# 1        Campeche  0.0    0.0    0.0     0.00     0.00     2.39    39.00
# 2  Aguascalientes  0.0    0.0    0.0     0.00     0.00    10.04    40.62
# 3         Sinaloa  0.0    0.0    0.0     0.75     2.21     4.63    32.01
# 4         Durango  0.0    0.0    0.0     0.00     0.00     0.00    20.21
#
#    45 - 49  50 - 59  60 - 64  65 y +  incidencia
# 0   233.48   198.33   218.52  163.75       80.46
# 1   171.34   217.39   353.43  176.49       77.14
# 2   313.00   178.87   226.30  114.59       74.37
# 3    72.38    90.67   116.08   75.69       39.84
# 4    71.22   114.68    60.76  105.28       36.20

# %%
morbilidad_16 = pd.read_csv('d:/Equipo_2_P2/DATA/Morbilidad_2013_2019/csv/morbilidad_2016.csv', 
                            encoding = 'latin-1', header = 2)
morbilidad_16 = morbilidad_16.rename(columns = dicc_nombre)
morbilidad_16 = morbilidad_16.sort_values(by="incidencia",ascending =False).reset_index(drop = True)

# como me encontré unos "N.A" dentro de algunas columnas las limpie usando .to_numeric, 
# exceptuando la primer fila, que es la de los estados
for elemento in range(0, len(list(morbilidad_16))):
    if elemento != 0:
        morbilidad_16.iloc[:, elemento] = pd.to_numeric(morbilidad_16.iloc[: ,elemento], 
                                                        errors = 'coerce').fillna(value = 0)

# morbilidad_16['estado'] = estado
morbilidad_16.head(5)
# Out:
#            estado  < 1  1 - 4  5 - 9  10 - 14  15 - 19  20 - 24  25 - 44  \
# 0  Aguascalientes  0.0    0.0    0.0      0.0     0.00     0.00    65.61
# 1          Colima  0.0    0.0    0.0      6.4     0.00     0.00    37.47
# 2        Campeche  0.0    0.0    0.0      0.0     0.00     2.38    26.92
# 3       Chihuahua  0.0    0.0    0.0      0.0     3.62     3.74    36.58
# 4       Querétaro  0.0    0.0    0.0      0.0     0.00     1.06    32.95
#
#    45 - 49  50 - 59  60 - 64  65 y +  incidencia
# 0   650.08   285.07   216.03  310.86      134.35
# 1   108.73   194.10   264.23  164.84       70.16
# 2   158.31   118.06   199.46  111.55       51.32
# 3    88.45   107.90   120.03   82.47       45.58
# 4    87.77   119.76   122.38   96.49       43.70

# %%
morbilidad_17 = pd.read_csv('d:/Equipo_2_P2/DATA/Morbilidad_2013_2019/csv/morbilidad_2017.csv', 
                            encoding = 'latin-1', header = 2)
morbilidad_17 = morbilidad_17.rename(columns = dicc_nombre)
morbilidad_17 = morbilidad_17.sort_values(by="incidencia",ascending =False).reset_index(drop = True)

# como me encontré unos "N.A" dentro de algunas columnas las limpie usando .to_numeric, 
# exceptuando la primer fila, que es la de los estados
for elemento in range(0, len(list(morbilidad_17))):
    if elemento != 0:
        morbilidad_17.iloc[:, elemento] = pd.to_numeric(morbilidad_17.iloc[: ,elemento], 
                                                        errors = 'coerce').fillna(value = 0)

# morbilidad_17['estado'] = estado
morbilidad_17.head(5)
# Out:
#             estado  < 1  1 - 4  5 - 9  10 - 14  15 - 19  20 - 24  25 - 44  \
# 0           Colima  0.0    0.0    0.0     0.00     0.00     0.00    40.19
# 1        Chihuahua  0.0    0.0    0.0     0.59     1.81     8.67    27.08
# 2        Querétaro  0.0    0.0    0.0     0.00     1.07     3.19    23.24
# 3  Baja California  0.0    0.0    0.0     0.00     0.64     3.11    25.02
# 4          Sinaloa  0.0    0.0    0.0     0.00     0.74     5.34    22.64
#
#    45 - 49  50 - 59  60 - 64  65 y +  incidencia
# 0   113.91   190.15   190.87  219.39       73.26
# 1    93.74    94.59   142.43  101.04       44.48
# 2    96.98   113.67   137.75   94.05       41.45
# 3    71.81   112.67   125.54   92.06       40.11
# 4    63.64   104.62   128.44   84.77       39.78

# %%
morbilidad_18 = pd.read_csv('d:/Equipo_2_P2/DATA/Morbilidad_2013_2019/csv/morbilidad_2018.csv', 
                            encoding = 'latin-1', header = 2)
morbilidad_18 = morbilidad_18.rename(columns = dicc_nombre)
morbilidad_18 = morbilidad_18.sort_values(by="incidencia",ascending =False).reset_index(drop = True)

# como me encontré unos "N.A" dentro de algunas columnas las limpie usando .to_numeric, 
# exceptuando la primer fila, que es la de los estados
for elemento in range(0, len(list(morbilidad_18))):
    if elemento != 0:
        morbilidad_18.iloc[:, elemento] = pd.to_numeric(morbilidad_18.iloc[: ,elemento], 
                                                        errors = 'coerce').fillna(value = 0)

# morbilidad_18['estado'] = estado
morbilidad_18.head(5)
# Out:
#       estado  < 1  1 - 4  5 - 9  10 - 14  15 - 19  20 - 24  25 - 44  45 - 49  \
# 0    Morelos  0.0    0.0    0.0      1.2     0.00    25.54    21.79   120.48
# 1     Colima  0.0    0.0    0.0      0.0     0.00     6.10    35.38   147.46
# 2   Campeche  0.0    0.0    0.0      0.0     0.00     6.99    30.75    90.27
# 3  Chihuahua  0.0    0.0    0.0      0.0     1.83     6.28    32.61    99.53
# 4    Durango  0.0    0.0    0.0      0.0     1.21     0.00    17.59   101.07
#
#    50 - 59  60 - 64  65 y +  incidencia
# 0   120.18   655.77  206.79       86.67
# 1   198.56   239.11  228.71       78.44
# 2   114.15   144.78  144.58       49.05
# 3    97.82   135.75  108.65       47.21
# 4   128.90   123.56  125.24       44.98

# %%
morbilidad_19 = pd.read_csv('d:/Equipo_2_P2/DATA/Morbilidad_2013_2019/csv/morbilidad_2019.csv', 
                            encoding = 'latin-1', header = 2)
morbilidad_19 = morbilidad_19.rename(columns = dicc_nombre)
morbilidad_19 = morbilidad_19.sort_values(by="incidencia",ascending =False).reset_index(drop = True)

# como me encontré unos "N.A" dentro de algunas columnas las limpie usando .to_numeric,
# exceptuando la primer fila, que es la de los estados
for elemento in range(0, len(list(morbilidad_19))):
    if elemento != 0:
        morbilidad_19.iloc[:, elemento] = pd.to_numeric(morbilidad_19.iloc[: ,elemento], 
                                                        errors = 'coerce').fillna(value = 0)

# morbilidad_19['estado'] = estado
morbilidad_19.head(5)
# Out:
#            estado  < 1  1 - 4  5 - 9  10 - 14  15 - 19  20 - 24  25 - 44  \
# 0         Morelos  0.0    0.0    0.0      0.0     0.00     4.67    40.26
# 1          Colima  0.0    0.0    0.0      0.0     3.12     0.00    66.40
# 2  Aguascalientes  0.0    0.0    0.0      0.0     0.00     1.57    30.24
# 3         Durango  0.0    0.0    0.0      0.0     0.00     0.00    22.22
# 4       Chihuahua  0.0    0.0    0.0      0.0     1.21     6.89    28.41
#
#    45 - 49  50 - 59  60 - 64  65 y +  incidencia
# 0    19.69    13.74  1493.68  309.54      122.81
# 1   131.23   226.04   492.58  322.17      112.36
# 2   118.77   157.10   164.18   91.61       51.92
# 3   100.90   129.96   176.54  123.78       49.32
# 4    96.98   105.24   134.09  130.02       48.90

# %% [markdown]
# ### De la lectura de los DS podemos ver de manera inmediata que el índice ha incrementado con los años y el estado que encabeza el índice de morbilidad es Campeche, por lo que podría ser otro target para comenzar una campaña de divulgación en la prevención del cáncer de mama.

# %% [markdown]
# ### **Pregunta de investigación 2**
# #### **2. ¿Cuál es la relación entre los gastos de salud y los resultados en su política en la lucha contra el cáncer?**
#
# En esta sección indagaremos cual ha sido el presupuesto para salud por estado de la República Mexicana y lo relacionaremos con los índices de mortalidad por cáncer de mama, con el fin de dilucidar si la dotación de presupuesto para combatir esta enfermedad ha sido adecuada.

# %% [markdown]
# #### **Dataset 1:**
# Gasto en Salud en el Sistema Nacional de Salud, México
# - Observaciones: Estados de la República
# - Periodo: 1993-2017
# - Archivo: "1._GFF_01_2017_A_CONS_O.csv"
# - Fuente: Dirección General de Información en Salud (DGIS) Secretaría de Salud (SSA).

# %% [markdown]
# ##### **I. Carga de datos**

# %%
### PRIMER DATASET: DGIS (2019). "Gasto en Salud, 1993-2017 (miles de pesos constantes, 2017=100)"
## I.Cargar datos en formato csv
#ADVERTENCIA: Archivo en  latin-1
gasto_salud = pd.read_csv("https://raw.githubusercontent.com/Zoe-Garcia/Equipo_2_P2/main/DATA/SSA%20Mexico/1._GFF_01_2017_A_CONS_O.csv", sep=',', encoding='latin-1')
gasto_salud.head()
# Out:
#          Entidad Federativa     Año  \
# 0  Estados Unidos Mexicanos  1993.0
# 1            Aguascalientes  1993.0
# 2           Baja California  1993.0
# 3       Baja California Sur  1993.0
# 4                  Campeche  1993.0
#
#    Producto Interno Bruto                       (Miles de pesos)  \
# 0                                       8.767898e+09
# 1                                       7.937825e+07
# 2                                       2.260210e+08
# 3                                       4.308558e+07
# 4                                       9.559377e+07
#
#   Gasto Total en Salud\n(I.1 + I.2)  \
# 0                      488075321.91
# 1                              n.d.
# 2                              n.d.
# 3                              n.d.
# 4                              n.d.
#
#    I.1 Gasto Público Total en Salud\n(Miles de pesos)\n(1 + 2)  \
# 0                                       2.193766e+08
# 1                                       1.869821e+06
# 2                                       5.909306e+06
# 3                                       1.674915e+06
# 4                                       1.568642e+06
#
#    1. Gasto Total \n(A+B+C+D+E+F) con SS  \
# 0                            42489885.47
# 1                              244488.47
# 2                              524751.50
# 3                              312689.42
# 4                              306722.46
#
#    A. Advo. Secretaria de Salud\n(Ramo 12) B. FASSA (Ramo 33)  \
# 0                              42489885.47               n.d.
# 1                                244488.47               n.d.
# 2                                524751.50               n.d.
# 3                                312689.42               n.d.
# 4                                306722.46               n.d.
#
#   C. IMSS \nProspera D. SEDENA\n(Ramo 7)  ... Unnamed: 56 Unnamed: 57  \
# 0               n.d.                n.d.  ...         NaN         NaN
# 1               n.d.                n.d.  ...         NaN         NaN
# 2               n.d.                n.d.  ...         NaN         NaN
# 3               n.d.                n.d.  ...         NaN         NaN
# 4               n.d.                n.d.  ...         NaN         NaN
#
#    Unnamed: 58  Unnamed: 59  Unnamed: 60  Unnamed: 61 Unnamed: 62 Unnamed: 63  \
# 0          NaN          NaN          NaN          NaN         NaN         NaN
# 1          NaN          NaN          NaN          NaN         NaN         NaN
# 2          NaN          NaN          NaN          NaN         NaN         NaN
# 3          NaN          NaN          NaN          NaN         NaN         NaN
# 4          NaN          NaN          NaN          NaN         NaN         NaN
#
#   Unnamed: 64 Unnamed: 65
# 0         NaN         NaN
# 1         NaN         NaN
# 2         NaN         NaN
# 3         NaN         NaN
# 4         NaN         NaN
#
# [5 rows x 66 columns]

# %% [markdown]
# ##### **II. Limpieza de datos**

# %%
##. II.Conocer DDBB y limpiarla
#Conocer tipo de datos y características generales del DataFrame
gasto_salud.shape
# Out:
# (833, 66)

# %%
#Tipo de datos
gasto_salud.dtypes
# Out:
# Entidad Federativa                                                object
# Año                                                              float64
# Producto Interno Bruto                       (Miles de pesos)    float64
# Gasto Total en Salud\n(I.1 + I.2)                                 object
# I.1 Gasto Público Total en Salud\n(Miles de pesos)\n(1 + 2)      float64
#                                                                   ...
# Unnamed: 61                                                      float64
# Unnamed: 62                                                      float64
# Unnamed: 63                                                      float64
# Unnamed: 64                                                      float64
# Unnamed: 65                                                      float64
# Length: 66, dtype: object

# %%
#Columnas
gasto_salud.columns
# Out:
# Index(['Entidad Federativa', 'Año',
#        'Producto Interno Bruto                       (Miles de pesos)',
#        'Gasto Total en Salud\n(I.1 + I.2)',
#        'I.1 Gasto Público Total en Salud\n(Miles de pesos)\n(1 + 2)',
#        '1. Gasto Total \n(A+B+C+D+E+F) con SS',
#        'A. Advo. Secretaria de Salud\n(Ramo 12)', 'B. FASSA (Ramo 33)',
#        'C. IMSS \nProspera', 'D. SEDENA\n(Ramo 7)', 'E. SEMAR\n(Ramo 13)',
#        'F. Gasto \nEstatal', '2. Gasto Total\n(A+B+C+D+E) sin SS', 'A. IMSS',
#        'B. ISSSTE', 'C. PEMEX', 'D. ISSFAM', 'E. ISSES',
#        'I.2 Gasto Privado Total en Salud\n(Miles de pesos constantes)\n(A + B + C)',
#        'A. Gasto de los Hogares e ISFL', 'B. Cuotas de Recuperación',
#        'C. Pago de Primas', 'Gasto  público total en salud como % del PIB',
#        'Gasto total en salud como % del PIB',
#        'Gasto público total en salud como % del gasto total en salud',
#        'Gasto público total en salud como % del gasto público total',
#        'Gasto público en salud per cápita para población con seguridad social',
#        'Gasto público en salud per cápita para población sin seguridad social ',
#        'Gasto público en salud per cápita total',
#        'Aportación federal al financiamiento de la salud de la población sin seguridad social (%)',
#        'Gasto privado en salud per cápita', 'Unnamed: 31', 'Unnamed: 32',
#        'Unnamed: 33', 'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36',
#        'Unnamed: 37', 'Unnamed: 38', 'Unnamed: 39', 'Unnamed: 40',
#        'Unnamed: 41', 'Unnamed: 42', 'Unnamed: 43', 'Unnamed: 44',
#        'Unnamed: 45', 'Unnamed: 46', 'Unnamed: 47', 'Unnamed: 48',
#        'Unnamed: 49', 'Unnamed: 50', 'Unnamed: 51', 'Unnamed: 52',
#        'Unnamed: 53', 'Unnamed: 54', 'Unnamed: 55', 'Unnamed: 56',
#        'Unnamed: 57', 'Unnamed: 58', 'Unnamed: 59', 'Unnamed: 60',
#        'Unnamed: 61', 'Unnamed: 62', 'Unnamed: 63', 'Unnamed: 64',
#        'Unnamed: 65'],
#       dtype='object')

# %%
#Contar NaN
gasto_salud.isna()
# Out:
#      Entidad Federativa    Año  \
# 0                 False  False
# 1                 False  False
# 2                 False  False
# 3                 False  False
# 4                 False  False
# ..                  ...    ...
# 828               False  False
# 829               False  False
# 830               False  False
# 831               False  False
# 832                True   True
#
#      Producto Interno Bruto                       (Miles de pesos)  \
# 0                                                False
# 1                                                False
# 2                                                False
# 3                                                False
# 4                                                False
# ..                                                 ...
# 828                                              False
# 829                                              False
# 830                                              False
# 831                                              False
# 832                                               True
#
#      Gasto Total en Salud\n(I.1 + I.2)  \
# 0                                False
# 1                                False
# 2                                False
# 3                                False
# 4                                False
# ..                                 ...
# 828                              False
# 829                              False
# 830                              False
# 831                              False
# 832                               True
#
#      I.1 Gasto Público Total en Salud\n(Miles de pesos)\n(1 + 2)  \
# 0                                                False
# 1                                                False
# 2                                                False
# 3                                                False
# 4                                                False
# ..                                                 ...
# 828                                              False
# 829                                              False
# 830                                              False
# 831                                              False
# 832                                               True
#
#      1. Gasto Total \n(A+B+C+D+E+F) con SS  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                    False
# ..                                     ...
# 828                                  False
# 829                                  False
# 830                                  False
# 831                                  False
# 832                                   True
#
#      A. Advo. Secretaria de Salud\n(Ramo 12)  B. FASSA (Ramo 33)  \
# 0                                      False               False
# 1                                      False               False
# 2                                      False               False
# 3                                      False               False
# 4                                      False               False
# ..                                       ...                 ...
# 828                                    False               False
# 829                                    False               False
# 830                                    False               False
# 831                                    False               False
# 832                                     True                True
#
#      C. IMSS \nProspera  D. SEDENA\n(Ramo 7)  ...  Unnamed: 56  Unnamed: 57  \
# 0                 False                False  ...         True         True
# 1                 False                False  ...         True         True
# 2                 False                False  ...         True         True
# 3                 False                False  ...         True         True
# 4                 False                False  ...         True         True
# ..                  ...                  ...  ...          ...          ...
# 828               False                False  ...         True         True
# 829               False                False  ...         True         True
# 830               False                False  ...         True         True
# 831               False                False  ...         True         True
# 832                True                 True  ...         True         True
#
#      Unnamed: 58  Unnamed: 59  Unnamed: 60  Unnamed: 61  Unnamed: 62  \
# 0           True         True         True         True         True
# 1           True         True         True         True         True
# 2           True         True         True         True         True
# 3           True         True         True         True         True
# 4           True         True         True         True         True
# ..           ...          ...          ...          ...          ...
# 828         True         True         True         True         True
# 829         True         True         True         True         True
# 830         True         True         True         True         True
# 831         True         True         True         True         True
# 832         True         True         True         True         True
#
#      Unnamed: 63  Unnamed: 64  Unnamed: 65
# 0           True         True         True
# 1           True         True         True
# 2           True         True         True
# 3           True         True         True
# 4           True         True         True
# ..           ...          ...          ...
# 828         True         True         True
# 829         True         True         True
# 830         True         True         True
# 831         True         True         True
# 832         True         True         True
#
# [833 rows x 66 columns]

# %%
#Sumar NaN por columna
gasto_salud.isna().sum(axis=0)
#Nota: Columnas "Unnamed" contienen 833 NaN
# Out:
# Entidad Federativa                                                 1
# Año                                                                1
# Producto Interno Bruto                       (Miles de pesos)      8
# Gasto Total en Salud\n(I.1 + I.2)                                  1
# I.1 Gasto Público Total en Salud\n(Miles de pesos)\n(1 + 2)        1
#                                                                 ...
# Unnamed: 61                                                      833
# Unnamed: 62                                                      833
# Unnamed: 63                                                      833
# Unnamed: 64                                                      833
# Unnamed: 65                                                      833
# Length: 66, dtype: int64

# %%
#Sumar NaN por fila
gasto_salud.isna().sum(axis=1)
# Out:
# 0      35
# 1      36
# 2      36
# 3      36
# 4      35
#        ..
# 828    37
# 829    36
# 830    35
# 831    37
# 832    66
# Length: 833, dtype: int64

# %%
#Eliminar columnas con todos los valores NaN
gasto_salud.dropna(axis=1, how='all')
#Nota: Este proceso elimina las columnas sin datos desde 'Unnamed: 31' hasta 'Unnamed: 65'
# Out:
#                   Entidad Federativa     Año  \
# 0           Estados Unidos Mexicanos  1993.0
# 1                     Aguascalientes  1993.0
# 2                    Baja California  1993.0
# 3                Baja California Sur  1993.0
# 4                           Campeche  1993.0
# ..                               ...     ...
# 828                         Tlaxcala  2017.0
# 829  Veracruz de Ignacio de la Llave  2017.0
# 830                          Yucatán  2017.0
# 831                        Zacatecas  2017.0
# 832                              NaN     NaN
#
#      Producto Interno Bruto                       (Miles de pesos)  \
# 0                                         8.767898e+09
# 1                                         7.937825e+07
# 2                                         2.260210e+08
# 3                                         4.308558e+07
# 4                                         9.559377e+07
# ..                                                 ...
# 828                                       1.154003e+08
# 829                                       9.402165e+08
# 830                                       3.004113e+08
# 831                                       1.971711e+08
# 832                                                NaN
#
#     Gasto Total en Salud\n(I.1 + I.2)  \
# 0                        488075321.91
# 1                                n.d.
# 2                                n.d.
# 3                                n.d.
# 4                                n.d.
# ..                                ...
# 828                              n.d.
# 829                              n.d.
# 830                              n.d.
# 831                              n.d.
# 832                               NaN
#
#      I.1 Gasto Público Total en Salud\n(Miles de pesos)\n(1 + 2)  \
# 0                                         2.193766e+08
# 1                                         1.869821e+06
# 2                                         5.909306e+06
# 3                                         1.674915e+06
# 4                                         1.568642e+06
# ..                                                 ...
# 828                                       5.743768e+06
# 829                                       3.682741e+07
# 830                                       1.276704e+07
# 831                                       7.389037e+06
# 832                                                NaN
#
#      1. Gasto Total \n(A+B+C+D+E+F) con SS  \
# 0                              42489885.47
# 1                                244488.47
# 2                                524751.50
# 3                                312689.42
# 4                                306722.46
# ..                                     ...
# 828                             3514829.33
# 829                            19985862.61
# 830                             5922854.79
# 831                             4601811.37
# 832                                    NaN
#
#      A. Advo. Secretaria de Salud\n(Ramo 12) B. FASSA (Ramo 33)  \
# 0                                42489885.47               n.d.
# 1                                  244488.47               n.d.
# 2                                  524751.50               n.d.
# 3                                  312689.42               n.d.
# 4                                  306722.46               n.d.
# ..                                       ...                ...
# 828                               1726101.32         1593398.56
# 829                               8549440.32         6180150.09
# 830                               2060160.68         1929417.46
# 831                               1283617.56         2199624.15
# 832                                      NaN                NaN
#
#     C. IMSS \nProspera D. SEDENA\n(Ramo 7)  ... C. Pago de Primas  \
# 0                 n.d.                n.d.  ...        9025163.54
# 1                 n.d.                n.d.  ...              n.d.
# 2                 n.d.                n.d.  ...              n.d.
# 3                 n.d.                n.d.  ...              n.d.
# 4                 n.d.                n.d.  ...              n.d.
# ..                 ...                 ...  ...               ...
# 828            8231.84                n.d.  ...          54795.16
# 829         1322403.18                n.d.  ...         730464.20
# 830          505049.00                n.d.  ...         827652.08
# 831          542541.22                n.d.  ...         101928.74
# 832                NaN                 NaN  ...               NaN
#
#     Gasto  público total en salud como % del PIB  \
# 0                                            2.5
# 1                                            2.4
# 2                                            2.6
# 3                                            3.9
# 4                                            1.6
# ..                                           ...
# 828                                          5.0
# 829                                          3.9
# 830                                          4.2
# 831                                          3.7
# 832                                          NaN
#
#      Gasto total en salud como % del PIB  \
# 0                                    5.6
# 1                                   n.d.
# 2                                   n.d.
# 3                                   n.d.
# 4                                   n.d.
# ..                                   ...
# 828                                 n.d.
# 829                                 n.d.
# 830                                 n.d.
# 831                                 n.d.
# 832                                  NaN
#
#      Gasto público total en salud como % del gasto total en salud  \
# 0                                                 44.9
# 1                                                 n.d.
# 2                                                 n.d.
# 3                                                 n.d.
# 4                                                 n.d.
# ..                                                 ...
# 828                                               n.d.
# 829                                               n.d.
# 830                                               n.d.
# 831                                               n.d.
# 832                                                NaN
#
#      Gasto público total en salud como % del gasto público total  \
# 0                                                 n.d.
# 1                                                 n.d.
# 2                                                 n.d.
# 3                                                 n.d.
# 4                                                 n.d.
# ..                                                 ...
# 828                                               28.3
# 829                                               17.5
# 830                                               22.3
# 831                                               25.7
# 832                                                NaN
#
#      Gasto público en salud per cápita para población con seguridad social  \
# 0                                                 n.d.
# 1                                                 n.d.
# 2                                                 n.d.
# 3                                                 n.d.
# 4                                                 n.d.
# ..                                                 ...
# 828                                            5543.41
# 829                                            5828.40
# 830                                            6239.37
# 831                                            4583.56
# 832                                                NaN
#
#     Gasto público en salud per cápita para población sin seguridad social   \
# 0                                                 n.d.
# 1                                                 n.d.
# 2                                                 n.d.
# 3                                                 n.d.
# 4                                                 n.d.
# ..                                                 ...
# 828                                            3858.30
# 829                                            3789.22
# 830                                            5505.01
# 831                                            4637.43
# 832                                                NaN
#
#     Gasto público en salud per cápita total  \
# 0                                   2394.92
# 1                                   2117.59
# 2                                   2990.13
# 3                                   4460.08
# 4                                   2617.30
# ..                                      ...
# 828                                 4374.31
# 829                                 4510.97
# 830                                 5875.74
# 831                                 4616.96
# 832                                     NaN
#
#     Aportación federal al financiamiento de la salud de la población sin seguridad social (%)  \
# 0                                                 n.d.
# 1                                                 n.d.
# 2                                                 n.d.
# 3                                                 n.d.
# 4                                                 n.d.
# ..                                                 ...
# 828                                               94.7
# 829                                               80.3
# 830                                               75.9
# 831                                               87.5
# 832                                                NaN
#
#     Gasto privado en salud per cápita
# 0                              2933.4
# 1                                n.d.
# 2                                n.d.
# 3                                n.d.
# 4                                n.d.
# ..                                ...
# 828                              n.d.
# 829                              n.d.
# 830                              n.d.
# 831                              n.d.
# 832                               NaN
#
# [833 rows x 31 columns]

# %%
#Guardar cambios de eliminación de columnas NaN en Data Frame
gasto_salud_drop = gasto_salud.dropna(axis=1, how='all')
gasto_salud_drop
# Out:
#                   Entidad Federativa     Año  \
# 0           Estados Unidos Mexicanos  1993.0
# 1                     Aguascalientes  1993.0
# 2                    Baja California  1993.0
# 3                Baja California Sur  1993.0
# 4                           Campeche  1993.0
# ..                               ...     ...
# 828                         Tlaxcala  2017.0
# 829  Veracruz de Ignacio de la Llave  2017.0
# 830                          Yucatán  2017.0
# 831                        Zacatecas  2017.0
# 832                              NaN     NaN
#
#      Producto Interno Bruto                       (Miles de pesos)  \
# 0                                         8.767898e+09
# 1                                         7.937825e+07
# 2                                         2.260210e+08
# 3                                         4.308558e+07
# 4                                         9.559377e+07
# ..                                                 ...
# 828                                       1.154003e+08
# 829                                       9.402165e+08
# 830                                       3.004113e+08
# 831                                       1.971711e+08
# 832                                                NaN
#
#     Gasto Total en Salud\n(I.1 + I.2)  \
# 0                        488075321.91
# 1                                n.d.
# 2                                n.d.
# 3                                n.d.
# 4                                n.d.
# ..                                ...
# 828                              n.d.
# 829                              n.d.
# 830                              n.d.
# 831                              n.d.
# 832                               NaN
#
#      I.1 Gasto Público Total en Salud\n(Miles de pesos)\n(1 + 2)  \
# 0                                         2.193766e+08
# 1                                         1.869821e+06
# 2                                         5.909306e+06
# 3                                         1.674915e+06
# 4                                         1.568642e+06
# ..                                                 ...
# 828                                       5.743768e+06
# 829                                       3.682741e+07
# 830                                       1.276704e+07
# 831                                       7.389037e+06
# 832                                                NaN
#
#      1. Gasto Total \n(A+B+C+D+E+F) con SS  \
# 0                              42489885.47
# 1                                244488.47
# 2                                524751.50
# 3                                312689.42
# 4                                306722.46
# ..                                     ...
# 828                             3514829.33
# 829                            19985862.61
# 830                             5922854.79
# 831                             4601811.37
# 832                                    NaN
#
#      A. Advo. Secretaria de Salud\n(Ramo 12) B. FASSA (Ramo 33)  \
# 0                                42489885.47               n.d.
# 1                                  244488.47               n.d.
# 2                                  524751.50               n.d.
# 3                                  312689.42               n.d.
# 4                                  306722.46               n.d.
# ..                                       ...                ...
# 828                               1726101.32         1593398.56
# 829                               8549440.32         6180150.09
# 830                               2060160.68         1929417.46
# 831                               1283617.56         2199624.15
# 832                                      NaN                NaN
#
#     C. IMSS \nProspera D. SEDENA\n(Ramo 7)  ... C. Pago de Primas  \
# 0                 n.d.                n.d.  ...        9025163.54
# 1                 n.d.                n.d.  ...              n.d.
# 2                 n.d.                n.d.  ...              n.d.
# 3                 n.d.                n.d.  ...              n.d.
# 4                 n.d.                n.d.  ...              n.d.
# ..                 ...                 ...  ...               ...
# 828            8231.84                n.d.  ...          54795.16
# 829         1322403.18                n.d.  ...         730464.20
# 830          505049.00                n.d.  ...         827652.08
# 831          542541.22                n.d.  ...         101928.74
# 832                NaN                 NaN  ...               NaN
#
#     Gasto  público total en salud como % del PIB  \
# 0                                            2.5
# 1                                            2.4
# 2                                            2.6
# 3                                            3.9
# 4                                            1.6
# ..                                           ...
# 828                                          5.0
# 829                                          3.9
# 830                                          4.2
# 831                                          3.7
# 832                                          NaN
#
#      Gasto total en salud como % del PIB  \
# 0                                    5.6
# 1                                   n.d.
# 2                                   n.d.
# 3                                   n.d.
# 4                                   n.d.
# ..                                   ...
# 828                                 n.d.
# 829                                 n.d.
# 830                                 n.d.
# 831                                 n.d.
# 832                                  NaN
#
#      Gasto público total en salud como % del gasto total en salud  \
# 0                                                 44.9
# 1                                                 n.d.
# 2                                                 n.d.
# 3                                                 n.d.
# 4                                                 n.d.
# ..                                                 ...
# 828                                               n.d.
# 829                                               n.d.
# 830                                               n.d.
# 831                                               n.d.
# 832                                                NaN
#
#      Gasto público total en salud como % del gasto público total  \
# 0                                                 n.d.
# 1                                                 n.d.
# 2                                                 n.d.
# 3                                                 n.d.
# 4                                                 n.d.
# ..                                                 ...
# 828                                               28.3
# 829                                               17.5
# 830                                               22.3
# 831                                               25.7
# 832                                                NaN
#
#      Gasto público en salud per cápita para población con seguridad social  \
# 0                                                 n.d.
# 1                                                 n.d.
# 2                                                 n.d.
# 3                                                 n.d.
# 4                                                 n.d.
# ..                                                 ...
# 828                                            5543.41
# 829                                            5828.40
# 830                                            6239.37
# 831                                            4583.56
# 832                                                NaN
#
#     Gasto público en salud per cápita para población sin seguridad social   \
# 0                                                 n.d.
# 1                                                 n.d.
# 2                                                 n.d.
# 3                                                 n.d.
# 4                                                 n.d.
# ..                                                 ...
# 828                                            3858.30
# 829                                            3789.22
# 830                                            5505.01
# 831                                            4637.43
# 832                                                NaN
#
#     Gasto público en salud per cápita total  \
# 0                                   2394.92
# 1                                   2117.59
# 2                                   2990.13
# 3                                   4460.08
# 4                                   2617.30
# ..                                      ...
# 828                                 4374.31
# 829                                 4510.97
# 830                                 5875.74
# 831                                 4616.96
# 832                                     NaN
#
#     Aportación federal al financiamiento de la salud de la población sin seguridad social (%)  \
# 0                                                 n.d.
# 1                                                 n.d.
# 2                                                 n.d.
# 3                                                 n.d.
# 4                                                 n.d.
# ..                                                 ...
# 828                                               94.7
# 829                                               80.3
# 830                                               75.9
# 831                                               87.5
# 832                                                NaN
#
#     Gasto privado en salud per cápita
# 0                              2933.4
# 1                                n.d.
# 2                                n.d.
# 3                                n.d.
# 4                                n.d.
# ..                                ...
# 828                              n.d.
# 829                              n.d.
# 830                              n.d.
# 831                              n.d.
# 832                               NaN
#
# [833 rows x 31 columns]

# %%
#Sin embargo, aparecen valores "n.d. que son en realidad "NaN"
#Remplazar n.d. por NaN para tener el verdadero conteo de nulos
gasto_salud_drop = gasto_salud_drop.replace('n.d.', np.NaN)
gasto_salud_drop.head()
# Out:
#          Entidad Federativa     Año  \
# 0  Estados Unidos Mexicanos  1993.0
# 1            Aguascalientes  1993.0
# 2           Baja California  1993.0
# 3       Baja California Sur  1993.0
# 4                  Campeche  1993.0
#
#    Producto Interno Bruto                       (Miles de pesos)  \
# 0                                       8.767898e+09
# 1                                       7.937825e+07
# 2                                       2.260210e+08
# 3                                       4.308558e+07
# 4                                       9.559377e+07
#
#   Gasto Total en Salud\n(I.1 + I.2)  \
# 0                      488075321.91
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
#
#    I.1 Gasto Público Total en Salud\n(Miles de pesos)\n(1 + 2)  \
# 0                                       2.193766e+08
# 1                                       1.869821e+06
# 2                                       5.909306e+06
# 3                                       1.674915e+06
# 4                                       1.568642e+06
#
#    1. Gasto Total \n(A+B+C+D+E+F) con SS  \
# 0                            42489885.47
# 1                              244488.47
# 2                              524751.50
# 3                              312689.42
# 4                              306722.46
#
#    A. Advo. Secretaria de Salud\n(Ramo 12) B. FASSA (Ramo 33)  \
# 0                              42489885.47                NaN
# 1                                244488.47                NaN
# 2                                524751.50                NaN
# 3                                312689.42                NaN
# 4                                306722.46                NaN
#
#   C. IMSS \nProspera D. SEDENA\n(Ramo 7)  ... C. Pago de Primas  \
# 0                NaN                 NaN  ...        9025163.54
# 1                NaN                 NaN  ...               NaN
# 2                NaN                 NaN  ...               NaN
# 3                NaN                 NaN  ...               NaN
# 4                NaN                 NaN  ...               NaN
#
#   Gasto  público total en salud como % del PIB  \
# 0                                          2.5
# 1                                          2.4
# 2                                          2.6
# 3                                          3.9
# 4                                          1.6
#
#    Gasto total en salud como % del PIB  \
# 0                                  5.6
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
#
#    Gasto público total en salud como % del gasto total en salud  \
# 0                                               44.9
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Gasto público total en salud como % del gasto público total  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Gasto público en salud per cápita para población con seguridad social  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Gasto público en salud per cápita para población sin seguridad social   \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Gasto público en salud per cápita total  \
# 0                                 2394.92
# 1                                 2117.59
# 2                                 2990.13
# 3                                 4460.08
# 4                                 2617.30
#
#   Aportación federal al financiamiento de la salud de la población sin seguridad social (%)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Gasto privado en salud per cápita
# 0                            2933.4
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
#
# [5 rows x 31 columns]

# %%
#Repetir el proceso anterior de limpieza de columnas con NaN
gasto_salud_drop = gasto_salud_drop.dropna(axis=1, how='all')
gasto_salud_drop.head(4)
# Out:
#          Entidad Federativa     Año  \
# 0  Estados Unidos Mexicanos  1993.0
# 1            Aguascalientes  1993.0
# 2           Baja California  1993.0
# 3       Baja California Sur  1993.0
#
#    Producto Interno Bruto                       (Miles de pesos)  \
# 0                                       8.767898e+09
# 1                                       7.937825e+07
# 2                                       2.260210e+08
# 3                                       4.308558e+07
#
#   Gasto Total en Salud\n(I.1 + I.2)  \
# 0                      488075321.91
# 1                               NaN
# 2                               NaN
# 3                               NaN
#
#    I.1 Gasto Público Total en Salud\n(Miles de pesos)\n(1 + 2)  \
# 0                                       2.193766e+08
# 1                                       1.869821e+06
# 2                                       5.909306e+06
# 3                                       1.674915e+06
#
#    1. Gasto Total \n(A+B+C+D+E+F) con SS  \
# 0                            42489885.47
# 1                              244488.47
# 2                              524751.50
# 3                              312689.42
#
#    A. Advo. Secretaria de Salud\n(Ramo 12) B. FASSA (Ramo 33)  \
# 0                              42489885.47                NaN
# 1                                244488.47                NaN
# 2                                524751.50                NaN
# 3                                312689.42                NaN
#
#   C. IMSS \nProspera D. SEDENA\n(Ramo 7)  ... C. Pago de Primas  \
# 0                NaN                 NaN  ...        9025163.54
# 1                NaN                 NaN  ...               NaN
# 2                NaN                 NaN  ...               NaN
# 3                NaN                 NaN  ...               NaN
#
#   Gasto  público total en salud como % del PIB  \
# 0                                          2.5
# 1                                          2.4
# 2                                          2.6
# 3                                          3.9
#
#    Gasto total en salud como % del PIB  \
# 0                                  5.6
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
#
#    Gasto público total en salud como % del gasto total en salud  \
# 0                                               44.9
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
#
#    Gasto público total en salud como % del gasto público total  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
#
#    Gasto público en salud per cápita para población con seguridad social  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
#
#   Gasto público en salud per cápita para población sin seguridad social   \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
#
#   Gasto público en salud per cápita total  \
# 0                                 2394.92
# 1                                 2117.59
# 2                                 2990.13
# 3                                 4460.08
#
#   Aportación federal al financiamiento de la salud de la población sin seguridad social (%)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
#
#   Gasto privado en salud per cápita
# 0                            2933.4
# 1                               NaN
# 2                               NaN
# 3                               NaN
#
# [4 rows x 31 columns]

# %%
#Eliminar filas con todos los valores NaN
gasto_salud_drop.dropna(axis=0, how='all')
#Nota: Este proceso elimina la úlitma fila sin información, índice 832
# Out:
#                   Entidad Federativa     Año  \
# 0           Estados Unidos Mexicanos  1993.0
# 1                     Aguascalientes  1993.0
# 2                    Baja California  1993.0
# 3                Baja California Sur  1993.0
# 4                           Campeche  1993.0
# ..                               ...     ...
# 827                       Tamaulipas  2017.0
# 828                         Tlaxcala  2017.0
# 829  Veracruz de Ignacio de la Llave  2017.0
# 830                          Yucatán  2017.0
# 831                        Zacatecas  2017.0
#
#      Producto Interno Bruto                       (Miles de pesos)  \
# 0                                         8.767898e+09
# 1                                         7.937825e+07
# 2                                         2.260210e+08
# 3                                         4.308558e+07
# 4                                         9.559377e+07
# ..                                                 ...
# 827                                       6.078901e+08
# 828                                       1.154003e+08
# 829                                       9.402165e+08
# 830                                       3.004113e+08
# 831                                       1.971711e+08
#
#     Gasto Total en Salud\n(I.1 + I.2)  \
# 0                        488075321.91
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
# ..                                ...
# 827                               NaN
# 828                               NaN
# 829                               NaN
# 830                               NaN
# 831                               NaN
#
#      I.1 Gasto Público Total en Salud\n(Miles de pesos)\n(1 + 2)  \
# 0                                         2.193766e+08
# 1                                         1.869821e+06
# 2                                         5.909306e+06
# 3                                         1.674915e+06
# 4                                         1.568642e+06
# ..                                                 ...
# 827                                       1.934230e+07
# 828                                       5.743768e+06
# 829                                       3.682741e+07
# 830                                       1.276704e+07
# 831                                       7.389037e+06
#
#      1. Gasto Total \n(A+B+C+D+E+F) con SS  \
# 0                              42489885.47
# 1                                244488.47
# 2                                524751.50
# 3                                312689.42
# 4                                306722.46
# ..                                     ...
# 827                             8805405.53
# 828                             3514829.33
# 829                            19985862.61
# 830                             5922854.79
# 831                             4601811.37
#
#      A. Advo. Secretaria de Salud\n(Ramo 12) B. FASSA (Ramo 33)  \
# 0                                42489885.47                NaN
# 1                                  244488.47                NaN
# 2                                  524751.50                NaN
# 3                                  312689.42                NaN
# 4                                  306722.46                NaN
# ..                                       ...                ...
# 827                               2833516.97         2870723.12
# 828                               1726101.32         1593398.56
# 829                               8549440.32         6180150.09
# 830                               2060160.68         1929417.46
# 831                               1283617.56         2199624.15
#
#     C. IMSS \nProspera D. SEDENA\n(Ramo 7)  ... C. Pago de Primas  \
# 0                  NaN                 NaN  ...        9025163.54
# 1                  NaN                 NaN  ...               NaN
# 2                  NaN                 NaN  ...               NaN
# 3                  NaN                 NaN  ...               NaN
# 4                  NaN                 NaN  ...               NaN
# ..                 ...                 ...  ...               ...
# 827          357945.44                 NaN  ...        1544719.11
# 828            8231.84                 NaN  ...          54795.16
# 829         1322403.18                 NaN  ...         730464.20
# 830          505049.00                 NaN  ...         827652.08
# 831          542541.22                 NaN  ...         101928.74
#
#     Gasto  público total en salud como % del PIB  \
# 0                                            2.5
# 1                                            2.4
# 2                                            2.6
# 3                                            3.9
# 4                                            1.6
# ..                                           ...
# 827                                          3.2
# 828                                          5.0
# 829                                          3.9
# 830                                          4.2
# 831                                          3.7
#
#      Gasto total en salud como % del PIB  \
# 0                                    5.6
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# ..                                   ...
# 827                                  NaN
# 828                                  NaN
# 829                                  NaN
# 830                                  NaN
# 831                                  NaN
#
#      Gasto público total en salud como % del gasto total en salud  \
# 0                                                 44.9
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 827                                                NaN
# 828                                                NaN
# 829                                                NaN
# 830                                                NaN
# 831                                                NaN
#
#      Gasto público total en salud como % del gasto público total  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 827                                               18.2
# 828                                               28.3
# 829                                               17.5
# 830                                               22.3
# 831                                               25.7
#
#      Gasto público en salud per cápita para población con seguridad social  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 827                                            5182.16
# 828                                            5543.41
# 829                                            5828.40
# 830                                            6239.37
# 831                                            4583.56
#
#     Gasto público en salud per cápita para población sin seguridad social   \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 827                                            5540.42
# 828                                            3858.30
# 829                                            3789.22
# 830                                            5505.01
# 831                                            4637.43
#
#     Gasto público en salud per cápita total  \
# 0                                   2394.92
# 1                                   2117.59
# 2                                   2990.13
# 3                                   4460.08
# 4                                   2617.30
# ..                                      ...
# 827                                 5339.33
# 828                                 4374.31
# 829                                 4510.97
# 830                                 5875.74
# 831                                 4616.96
#
#     Aportación federal al financiamiento de la salud de la población sin seguridad social (%)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 827                                               68.8
# 828                                               94.7
# 829                                               80.3
# 830                                               75.9
# 831                                               87.5
#
#     Gasto privado en salud per cápita
# 0                              2933.4
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
# ..                                ...
# 827                               NaN
# 828                               NaN
# 829                               NaN
# 830                               NaN
# 831                               NaN
#
# [832 rows x 31 columns]

# %%
#Guardar cambios de eliminación de fila NaN en Data Frame
gasto_salud_drop = gasto_salud_drop.dropna(axis=0, how='all')
gasto_salud_drop.tail()
# Out:
#                   Entidad Federativa     Año  \
# 827                       Tamaulipas  2017.0
# 828                         Tlaxcala  2017.0
# 829  Veracruz de Ignacio de la Llave  2017.0
# 830                          Yucatán  2017.0
# 831                        Zacatecas  2017.0
#
#      Producto Interno Bruto                       (Miles de pesos)  \
# 827                                        607890090.0
# 828                                        115400274.0
# 829                                        940216541.0
# 830                                        300411279.0
# 831                                        197171148.0
#
#     Gasto Total en Salud\n(I.1 + I.2)  \
# 827                               NaN
# 828                               NaN
# 829                               NaN
# 830                               NaN
# 831                               NaN
#
#      I.1 Gasto Público Total en Salud\n(Miles de pesos)\n(1 + 2)  \
# 827                                        19342297.56
# 828                                         5743767.63
# 829                                        36827405.28
# 830                                        12767041.69
# 831                                         7389037.38
#
#      1. Gasto Total \n(A+B+C+D+E+F) con SS  \
# 827                             8805405.53
# 828                             3514829.33
# 829                            19985862.61
# 830                             5922854.79
# 831                             4601811.37
#
#      A. Advo. Secretaria de Salud\n(Ramo 12) B. FASSA (Ramo 33)  \
# 827                               2833516.97         2870723.12
# 828                               1726101.32         1593398.56
# 829                               8549440.32         6180150.09
# 830                               2060160.68         1929417.46
# 831                               1283617.56         2199624.15
#
#     C. IMSS \nProspera D. SEDENA\n(Ramo 7)  ... C. Pago de Primas  \
# 827          357945.44                 NaN  ...        1544719.11
# 828            8231.84                 NaN  ...          54795.16
# 829         1322403.18                 NaN  ...         730464.20
# 830          505049.00                 NaN  ...         827652.08
# 831          542541.22                 NaN  ...         101928.74
#
#     Gasto  público total en salud como % del PIB  \
# 827                                          3.2
# 828                                          5.0
# 829                                          3.9
# 830                                          4.2
# 831                                          3.7
#
#      Gasto total en salud como % del PIB  \
# 827                                  NaN
# 828                                  NaN
# 829                                  NaN
# 830                                  NaN
# 831                                  NaN
#
#      Gasto público total en salud como % del gasto total en salud  \
# 827                                                NaN
# 828                                                NaN
# 829                                                NaN
# 830                                                NaN
# 831                                                NaN
#
#      Gasto público total en salud como % del gasto público total  \
# 827                                               18.2
# 828                                               28.3
# 829                                               17.5
# 830                                               22.3
# 831                                               25.7
#
#      Gasto público en salud per cápita para población con seguridad social  \
# 827                                            5182.16
# 828                                            5543.41
# 829                                            5828.40
# 830                                            6239.37
# 831                                            4583.56
#
#     Gasto público en salud per cápita para población sin seguridad social   \
# 827                                            5540.42
# 828                                            3858.30
# 829                                            3789.22
# 830                                            5505.01
# 831                                            4637.43
#
#     Gasto público en salud per cápita total  \
# 827                                 5339.33
# 828                                 4374.31
# 829                                 4510.97
# 830                                 5875.74
# 831                                 4616.96
#
#     Aportación federal al financiamiento de la salud de la población sin seguridad social (%)  \
# 827                                               68.8
# 828                                               94.7
# 829                                               80.3
# 830                                               75.9
# 831                                               87.5
#
#     Gasto privado en salud per cápita
# 827                               NaN
# 828                               NaN
# 829                               NaN
# 830                               NaN
# 831                               NaN
#
# [5 rows x 31 columns]

# %%
#Contar nuevamente los NaN
gasto_salud_drop.isna().sum(axis=0)
# Out:
# Entidad Federativa                                                                             0
# Año                                                                                            0
# Producto Interno Bruto                       (Miles de pesos)                                  7
# Gasto Total en Salud\n(I.1 + I.2)                                                            807
# I.1 Gasto Público Total en Salud\n(Miles de pesos)\n(1 + 2)                                    0
# 1. Gasto Total \n(A+B+C+D+E+F) con SS                                                          0
# A. Advo. Secretaria de Salud\n(Ramo 12)                                                       22
# B. FASSA (Ramo 33)                                                                           172
# C. IMSS \nProspera                                                                           524
# D. SEDENA\n(Ramo 7)                                                                          817
# E. SEMAR\n(Ramo 13)                                                                          819
# F. Gasto \nEstatal                                                                           206
# 2. Gasto Total\n(A+B+C+D+E) sin SS                                                             7
# A. IMSS                                                                                        7
# B. ISSSTE                                                                                      7
# C. PEMEX                                                                                     154
# D. ISSFAM                                                                                    817
# E. ISSES                                                                                     788
# I.2 Gasto Privado Total en Salud\n(Miles de pesos constantes)\n(A + B + C)                   807
# A. Gasto de los Hogares e ISFL                                                               807
# B. Cuotas de Recuperación                                                                    271
# C. Pago de Primas                                                                            165
# Gasto  público total en salud como % del PIB                                                   7
# Gasto total en salud como % del PIB                                                          807
# Gasto público total en salud como % del gasto total en salud                                 775
# Gasto público total en salud como % del gasto público total                                   40
# Gasto público en salud per cápita para población con seguridad social                        204
# Gasto público en salud per cápita para población sin seguridad social                        204
# Gasto público en salud per cápita total                                                        0
# Aportación federal al financiamiento de la salud de la población sin seguridad social (%)    205
# Gasto privado en salud per cápita                                                            775
# dtype: int64

# %%
#Aún existen columnas con demasiados NaN. Asimismo, dichas columnas no son tan relevantes
#Se eliminan dichas columnas para poder tener un mejor análisis
gasto_salud_drop = gasto_salud_drop.drop(['Gasto Total en Salud\n(I.1 + I.2)', 
                                          'C. IMSS \nProspera', 'D. SEDENA\n(Ramo 7)', 
                                          'E. SEMAR\n(Ramo 13)', 'D. ISSFAM', 'E. ISSES', 
                                          'I.2 Gasto Privado Total en Salud\n(Miles de pesos constantes)\n(A + B + C)', 
                                          'A. Gasto de los Hogares e ISFL', 
                                          'Gasto total en salud como % del PIB', 
                                          'Gasto público total en salud como % del gasto total en salud', 
                                          'Gasto privado en salud per cápita'], axis=1)

# %%
#Contar nuevamente los NaN
gasto_salud_drop.isna().sum(axis=0)
# Out:
# Entidad Federativa                                                                             0
# Año                                                                                            0
# Producto Interno Bruto                       (Miles de pesos)                                  7
# I.1 Gasto Público Total en Salud\n(Miles de pesos)\n(1 + 2)                                    0
# 1. Gasto Total \n(A+B+C+D+E+F) con SS                                                          0
# A. Advo. Secretaria de Salud\n(Ramo 12)                                                       22
# B. FASSA (Ramo 33)                                                                           172
# F. Gasto \nEstatal                                                                           206
# 2. Gasto Total\n(A+B+C+D+E) sin SS                                                             7
# A. IMSS                                                                                        7
# B. ISSSTE                                                                                      7
# C. PEMEX                                                                                     154
# B. Cuotas de Recuperación                                                                    271
# C. Pago de Primas                                                                            165
# Gasto  público total en salud como % del PIB                                                   7
# Gasto público total en salud como % del gasto público total                                   40
# Gasto público en salud per cápita para población con seguridad social                        204
# Gasto público en salud per cápita para población sin seguridad social                        204
# Gasto público en salud per cápita total                                                        0
# Aportación federal al financiamiento de la salud de la población sin seguridad social (%)    205
# dtype: int64

# %%
#Evaluar nuevamente los NaN por fila
gasto_salud.isna().sum(axis=1)
# Out:
# 0      35
# 1      36
# 2      36
# 3      36
# 4      35
#        ..
# 828    37
# 829    36
# 830    35
# 831    37
# 832    66
# Length: 833, dtype: int64

# %%
#Identificar fila donde inicia año 2000
gasto_salud_drop.iloc[238]
# Out:
# Entidad Federativa                                                                           Estados Unidos Mexicanos
# Año                                                                                                            2000.0
# Producto Interno Bruto                       (Miles de pesos)                                      10983890601.299999
# I.1 Gasto Público Total en Salud\n(Miles de pesos)\n(1 + 2)                                              284322990.43
# 1. Gasto Total \n(A+B+C+D+E+F) con SS                                                                     92221099.75
# A. Advo. Secretaria de Salud\n(Ramo 12)                                                                   32524104.49
# B. FASSA (Ramo 33)                                                                                        45666769.87
# F. Gasto \nEstatal                                                                                        14030225.39
# 2. Gasto Total\n(A+B+C+D+E) sin SS                                                                       192101890.68
# A. IMSS                                                                                                  158199096.05
# B. ISSSTE                                                                                                 25106991.01
# C. PEMEX                                                                                                   8795803.61
# B. Cuotas de Recuperación                                                                                         NaN
# C. Pago de Primas                                                                                         15242292.93
# Gasto  público total en salud como % del PIB                                                                      2.6
# Gasto público total en salud como % del gasto público total                                                      16.6
# Gasto público en salud per cápita para población con seguridad social                                         3884.49
# Gasto público en salud per cápita para población sin seguridad social                                         1792.72
# Gasto público en salud per cápita total                                                                       2817.98
# Aportación federal al financiamiento de la salud de la población sin seguridad social (%)                        84.8
# Name: 238, dtype: object

# %%
# Eliminar filas con muchos NaN, correspondientes a los años 1993-1999, 
# para igualar periodo con el Segundo DataFrame sobre mortalidad
gasto_salud_drop = gasto_salud_drop.drop(gasto_salud_drop.index[range(238)])

# %%
gasto_salud_drop.head()
# Out:
#            Entidad Federativa     Año  \
# 238  Estados Unidos Mexicanos  2000.0
# 239            Aguascalientes  2000.0
# 240           Baja California  2000.0
# 241       Baja California Sur  2000.0
# 242                  Campeche  2000.0
#
#      Producto Interno Bruto                       (Miles de pesos)  \
# 238                                       1.098389e+10
# 239                                       1.233635e+08
# 240                                       3.617749e+08
# 241                                       5.392448e+07
# 242                                       1.191197e+08
#
#      I.1 Gasto Público Total en Salud\n(Miles de pesos)\n(1 + 2)  \
# 238                                       2.843230e+08
# 239                                       3.028818e+06
# 240                                       7.325541e+06
# 241                                       2.110065e+06
# 242                                       2.428181e+06
#
#      1. Gasto Total \n(A+B+C+D+E+F) con SS  \
# 238                            92221099.75
# 239                             1059039.52
# 240                             1142409.28
# 241                              548082.52
# 242                              984654.51
#
#      A. Advo. Secretaria de Salud\n(Ramo 12) B. FASSA (Ramo 33)  \
# 238                              32524104.49        45666769.87
# 239                                  6816.29          691829.84
# 240                                 58962.54         1035444.66
# 241                                  6526.28          519422.41
# 242                                149975.07          697430.08
#
#     F. Gasto \nEstatal  2. Gasto Total\n(A+B+C+D+E) sin SS       A. IMSS  \
# 238        14030225.39                        1.921019e+08  1.581991e+08
# 239          360393.39                        1.969779e+06  1.791865e+06
# 240           48002.07                        6.183132e+06  5.730923e+06
# 241           22133.83                        1.561983e+06  1.237632e+06
# 242          137249.36                        1.443527e+06  9.289885e+05
#
#        B. ISSSTE    C. PEMEX B. Cuotas de Recuperación C. Pago de Primas  \
# 238  25106991.01  8795803.61                       NaN       15242292.93
# 239    167010.80    10902.87                       NaN          49754.01
# 240    418176.84    34031.87                       NaN         225017.87
# 241    317848.31     6502.28                       NaN           5631.66
# 242    161987.19   352551.21                       NaN           1734.41
#
#      Gasto  público total en salud como % del PIB  \
# 238                                           2.6
# 239                                           2.5
# 240                                           2.0
# 241                                           3.9
# 242                                           2.0
#
#     Gasto público total en salud como % del gasto público total  \
# 238                                               16.6
# 239                                               12.8
# 240                                               17.6
# 241                                               17.3
# 242                                                7.0
#
#     Gasto público en salud per cápita para población con seguridad social  \
# 238                                            3884.49
# 239                                            3052.95
# 240                                            3720.76
# 241                                            4842.07
# 242                                            4392.01
#
#     Gasto público en salud per cápita para población sin seguridad social   \
# 238                                            1792.72
# 239                                            2915.51
# 240                                            1286.42
# 241                                            3809.58
# 242                                            2646.65
#
#      Gasto público en salud per cápita total  \
# 238                                  2817.98
# 239                                  3003.45
# 240                                  2872.94
# 241                                  4523.62
# 242                                  3465.33
#
#     Aportación federal al financiamiento de la salud de la población sin seguridad social (%)
# 238                                               84.8
# 239                                               66.0
# 240                                               95.8
# 241                                               96.0
# 242                                               86.1

# %%
#Evaluar nuevamente los NaN por columna
gasto_salud_drop.isna().sum(axis=0)
# Out:
# Entidad Federativa                                                                            0
# Año                                                                                           0
# Producto Interno Bruto                       (Miles de pesos)                                 0
# I.1 Gasto Público Total en Salud\n(Miles de pesos)\n(1 + 2)                                   0
# 1. Gasto Total \n(A+B+C+D+E+F) con SS                                                         0
# A. Advo. Secretaria de Salud\n(Ramo 12)                                                       0
# B. FASSA (Ramo 33)                                                                            0
# F. Gasto \nEstatal                                                                            1
# 2. Gasto Total\n(A+B+C+D+E) sin SS                                                            0
# A. IMSS                                                                                       0
# B. ISSSTE                                                                                     0
# C. PEMEX                                                                                     93
# B. Cuotas de Recuperación                                                                    33
# C. Pago de Primas                                                                             0
# Gasto  público total en salud como % del PIB                                                  0
# Gasto público total en salud como % del gasto público total                                   0
# Gasto público en salud per cápita para población con seguridad social                         0
# Gasto público en salud per cápita para población sin seguridad social                         0
# Gasto público en salud per cápita total                                                       0
# Aportación federal al financiamiento de la salud de la población sin seguridad social (%)     0
# dtype: int64

# %%
#Repetir proceso de eliminación de columnas con NaN numerosas
gasto_salud_drop = gasto_salud_drop.drop(['C. PEMEX'], axis=1)
gasto_salud_drop.head(3)
# Out:
#            Entidad Federativa     Año  \
# 238  Estados Unidos Mexicanos  2000.0
# 239            Aguascalientes  2000.0
# 240           Baja California  2000.0
#
#      Producto Interno Bruto                       (Miles de pesos)  \
# 238                                       1.098389e+10
# 239                                       1.233635e+08
# 240                                       3.617749e+08
#
#      I.1 Gasto Público Total en Salud\n(Miles de pesos)\n(1 + 2)  \
# 238                                       2.843230e+08
# 239                                       3.028818e+06
# 240                                       7.325541e+06
#
#      1. Gasto Total \n(A+B+C+D+E+F) con SS  \
# 238                            92221099.75
# 239                             1059039.52
# 240                             1142409.28
#
#      A. Advo. Secretaria de Salud\n(Ramo 12) B. FASSA (Ramo 33)  \
# 238                              32524104.49        45666769.87
# 239                                  6816.29          691829.84
# 240                                 58962.54         1035444.66
#
#     F. Gasto \nEstatal  2. Gasto Total\n(A+B+C+D+E) sin SS       A. IMSS  \
# 238        14030225.39                        1.921019e+08  1.581991e+08
# 239          360393.39                        1.969779e+06  1.791865e+06
# 240           48002.07                        6.183132e+06  5.730923e+06
#
#        B. ISSSTE B. Cuotas de Recuperación C. Pago de Primas  \
# 238  25106991.01                       NaN       15242292.93
# 239    167010.80                       NaN          49754.01
# 240    418176.84                       NaN         225017.87
#
#      Gasto  público total en salud como % del PIB  \
# 238                                           2.6
# 239                                           2.5
# 240                                           2.0
#
#     Gasto público total en salud como % del gasto público total  \
# 238                                               16.6
# 239                                               12.8
# 240                                               17.6
#
#     Gasto público en salud per cápita para población con seguridad social  \
# 238                                            3884.49
# 239                                            3052.95
# 240                                            3720.76
#
#     Gasto público en salud per cápita para población sin seguridad social   \
# 238                                            1792.72
# 239                                            2915.51
# 240                                            1286.42
#
#      Gasto público en salud per cápita total  \
# 238                                  2817.98
# 239                                  3003.45
# 240                                  2872.94
#
#     Aportación federal al financiamiento de la salud de la población sin seguridad social (%)
# 238                                               84.8
# 239                                               66.0
# 240                                               95.8

# %%
#Convertir en 0 los NaN de columnas 'F. Gasto \nEstatal' y 'B. Cuotas de Recuperación'
gasto_salud_drop['F. Gasto \nEstatal'] = gasto_salud_drop['F. Gasto \nEstatal'].fillna(0)
gasto_salud_drop['B. Cuotas de Recuperación'] = gasto_salud_drop['B. Cuotas de Recuperación'].fillna(0)

# %%
#Evaluar nuevamente los NaN por columna
gasto_salud_drop.isna().sum(axis=0)
#Nota: Obtenemos 0 NaN
# Out:
# Entidad Federativa                                                                           0
# Año                                                                                          0
# Producto Interno Bruto                       (Miles de pesos)                                0
# I.1 Gasto Público Total en Salud\n(Miles de pesos)\n(1 + 2)                                  0
# 1. Gasto Total \n(A+B+C+D+E+F) con SS                                                        0
# A. Advo. Secretaria de Salud\n(Ramo 12)                                                      0
# B. FASSA (Ramo 33)                                                                           0
# F. Gasto \nEstatal                                                                           0
# 2. Gasto Total\n(A+B+C+D+E) sin SS                                                           0
# A. IMSS                                                                                      0
# B. ISSSTE                                                                                    0
# B. Cuotas de Recuperación                                                                    0
# C. Pago de Primas                                                                            0
# Gasto  público total en salud como % del PIB                                                 0
# Gasto público total en salud como % del gasto público total                                  0
# Gasto público en salud per cápita para población con seguridad social                        0
# Gasto público en salud per cápita para población sin seguridad social                        0
# Gasto público en salud per cápita total                                                      0
# Aportación federal al financiamiento de la salud de la población sin seguridad social (%)    0
# dtype: int64

# %%
# Tipo de datos
gasto_salud_drop.dtypes
# Out:
# Entidad Federativa                                                                            object
# Año                                                                                          float64
# Producto Interno Bruto                       (Miles de pesos)                                float64
# I.1 Gasto Público Total en Salud\n(Miles de pesos)\n(1 + 2)                                  float64
# 1. Gasto Total \n(A+B+C+D+E+F) con SS                                                        float64
# A. Advo. Secretaria de Salud\n(Ramo 12)                                                      float64
# B. FASSA (Ramo 33)                                                                            object
# F. Gasto \nEstatal                                                                            object
# 2. Gasto Total\n(A+B+C+D+E) sin SS                                                           float64
# A. IMSS                                                                                      float64
# B. ISSSTE                                                                                    float64
# B. Cuotas de Recuperación                                                                     object
# C. Pago de Primas                                                                             object
# Gasto  público total en salud como % del PIB                                                 float64
# Gasto público total en salud como % del gasto público total                                   object
# Gasto público en salud per cápita para población con seguridad social                         object
# Gasto público en salud per cápita para población sin seguridad social                         object
# Gasto público en salud per cápita total                                                      float64
# Aportación federal al financiamiento de la salud de la población sin seguridad social (%)     object
# dtype: object

# %%
#Convertir 'Año' en datetime
gasto_salud_drop['Año'] = gasto_salud_drop['Año'].apply(np.int64)
gasto_salud_drop['Año'] = pd.to_datetime(gasto_salud_drop['Año'].astype(str), format='%Y')
gasto_salud_drop.head()
# Out:
#            Entidad Federativa        Año  \
# 238  Estados Unidos Mexicanos 2000-01-01
# 239            Aguascalientes 2000-01-01
# 240           Baja California 2000-01-01
# 241       Baja California Sur 2000-01-01
# 242                  Campeche 2000-01-01
#
#      Producto Interno Bruto                       (Miles de pesos)  \
# 238                                       1.098389e+10
# 239                                       1.233635e+08
# 240                                       3.617749e+08
# 241                                       5.392448e+07
# 242                                       1.191197e+08
#
#      I.1 Gasto Público Total en Salud\n(Miles de pesos)\n(1 + 2)  \
# 238                                       2.843230e+08
# 239                                       3.028818e+06
# 240                                       7.325541e+06
# 241                                       2.110065e+06
# 242                                       2.428181e+06
#
#      1. Gasto Total \n(A+B+C+D+E+F) con SS  \
# 238                            92221099.75
# 239                             1059039.52
# 240                             1142409.28
# 241                              548082.52
# 242                              984654.51
#
#      A. Advo. Secretaria de Salud\n(Ramo 12) B. FASSA (Ramo 33)  \
# 238                              32524104.49        45666769.87
# 239                                  6816.29          691829.84
# 240                                 58962.54         1035444.66
# 241                                  6526.28          519422.41
# 242                                149975.07          697430.08
#
#     F. Gasto \nEstatal  2. Gasto Total\n(A+B+C+D+E) sin SS       A. IMSS  \
# 238        14030225.39                        1.921019e+08  1.581991e+08
# 239          360393.39                        1.969779e+06  1.791865e+06
# 240           48002.07                        6.183132e+06  5.730923e+06
# 241           22133.83                        1.561983e+06  1.237632e+06
# 242          137249.36                        1.443527e+06  9.289885e+05
#
#        B. ISSSTE B. Cuotas de Recuperación C. Pago de Primas  \
# 238  25106991.01                         0       15242292.93
# 239    167010.80                         0          49754.01
# 240    418176.84                         0         225017.87
# 241    317848.31                         0           5631.66
# 242    161987.19                         0           1734.41
#
#      Gasto  público total en salud como % del PIB  \
# 238                                           2.6
# 239                                           2.5
# 240                                           2.0
# 241                                           3.9
# 242                                           2.0
#
#     Gasto público total en salud como % del gasto público total  \
# 238                                               16.6
# 239                                               12.8
# 240                                               17.6
# 241                                               17.3
# 242                                                7.0
#
#     Gasto público en salud per cápita para población con seguridad social  \
# 238                                            3884.49
# 239                                            3052.95
# 240                                            3720.76
# 241                                            4842.07
# 242                                            4392.01
#
#     Gasto público en salud per cápita para población sin seguridad social   \
# 238                                            1792.72
# 239                                            2915.51
# 240                                            1286.42
# 241                                            3809.58
# 242                                            2646.65
#
#      Gasto público en salud per cápita total  \
# 238                                  2817.98
# 239                                  3003.45
# 240                                  2872.94
# 241                                  4523.62
# 242                                  3465.33
#
#     Aportación federal al financiamiento de la salud de la población sin seguridad social (%)
# 238                                               84.8
# 239                                               66.0
# 240                                               95.8
# 241                                               96.0
# 242                                               86.1

# %%
# Nuevamente revisamos el tipo de datos
gasto_salud_drop.dtypes
# Out:
# Entidad Federativa                                                                                   object
# Año                                                                                          datetime64[ns]
# Producto Interno Bruto                       (Miles de pesos)                                       float64
# I.1 Gasto Público Total en Salud\n(Miles de pesos)\n(1 + 2)                                         float64
# 1. Gasto Total \n(A+B+C+D+E+F) con SS                                                               float64
# A. Advo. Secretaria de Salud\n(Ramo 12)                                                             float64
# B. FASSA (Ramo 33)                                                                                   object
# F. Gasto \nEstatal                                                                                   object
# 2. Gasto Total\n(A+B+C+D+E) sin SS                                                                  float64
# A. IMSS                                                                                             float64
# B. ISSSTE                                                                                           float64
# B. Cuotas de Recuperación                                                                            object
# C. Pago de Primas                                                                                    object
# Gasto  público total en salud como % del PIB                                                        float64
# Gasto público total en salud como % del gasto público total                                          object
# Gasto público en salud per cápita para población con seguridad social                                object
# Gasto público en salud per cápita para población sin seguridad social                                object
# Gasto público en salud per cápita total                                                             float64
# Aportación federal al financiamiento de la salud de la población sin seguridad social (%)            object
# dtype: object

# %%
#Convertir datos object en numéricos
gasto_salud_drop['B. FASSA (Ramo 33)'] = gasto_salud_drop['B. FASSA (Ramo 33)'].apply(np.float64)
gasto_salud_drop['F. Gasto \nEstatal'] = gasto_salud_drop['F. Gasto \nEstatal'].apply(np.float64)
gasto_salud_drop['B. Cuotas de Recuperación'] = gasto_salud_drop['B. Cuotas de Recuperación'].apply(np.float64)
gasto_salud_drop['C. Pago de Primas'] = gasto_salud_drop['C. Pago de Primas'].apply(np.float64)
gasto_salud_drop['Gasto público total en salud como % del gasto público total'] = gasto_salud_drop['Gasto público total en salud como % del gasto público total'].apply(np.float64)
gasto_salud_drop['Gasto público en salud per cápita para población con seguridad social'] = gasto_salud_drop['Gasto público en salud per cápita para población con seguridad social'].apply(np.float64)
gasto_salud_drop['Gasto público en salud per cápita para población sin seguridad social '] = gasto_salud_drop['Gasto público en salud per cápita para población sin seguridad social '].apply(np.float64)
gasto_salud_drop['Aportación federal al financiamiento de la salud de la población sin seguridad social (%)'] = gasto_salud_drop['Aportación federal al financiamiento de la salud de la población sin seguridad social (%)'].apply(np.float64)

# %%
#Nuevamente revisamos el tipo de datos
gasto_salud_drop.dtypes
#Todos los tipos de datos object se modificaron correctamente a float64
# Out:
# Entidad Federativa                                                                                   object
# Año                                                                                          datetime64[ns]
# Producto Interno Bruto                       (Miles de pesos)                                       float64
# I.1 Gasto Público Total en Salud\n(Miles de pesos)\n(1 + 2)                                         float64
# 1. Gasto Total \n(A+B+C+D+E+F) con SS                                                               float64
# A. Advo. Secretaria de Salud\n(Ramo 12)                                                             float64
# B. FASSA (Ramo 33)                                                                                  float64
# F. Gasto \nEstatal                                                                                  float64
# 2. Gasto Total\n(A+B+C+D+E) sin SS                                                                  float64
# A. IMSS                                                                                             float64
# B. ISSSTE                                                                                           float64
# B. Cuotas de Recuperación                                                                           float64
# C. Pago de Primas                                                                                   float64
# Gasto  público total en salud como % del PIB                                                        float64
# Gasto público total en salud como % del gasto público total                                         float64
# Gasto público en salud per cápita para población con seguridad social                               float64
# Gasto público en salud per cápita para población sin seguridad social                               float64
# Gasto público en salud per cápita total                                                             float64
# Aportación federal al financiamiento de la salud de la población sin seguridad social (%)           float64
# dtype: object

# %%
#Dimensión del DataFrame final
gasto_salud_drop.shape
#594 x 19
# Out:
# (594, 19)

# %%
gasto_salud_drop.columns
# Out:
# Index(['Entidad Federativa', 'Año',
#        'Producto Interno Bruto                       (Miles de pesos)',
#        'I.1 Gasto Público Total en Salud\n(Miles de pesos)\n(1 + 2)',
#        '1. Gasto Total \n(A+B+C+D+E+F) con SS',
#        'A. Advo. Secretaria de Salud\n(Ramo 12)', 'B. FASSA (Ramo 33)',
#        'F. Gasto \nEstatal', '2. Gasto Total\n(A+B+C+D+E) sin SS', 'A. IMSS',
#        'B. ISSSTE', 'B. Cuotas de Recuperación', 'C. Pago de Primas',
#        'Gasto  público total en salud como % del PIB',
#        'Gasto público total en salud como % del gasto público total',
#        'Gasto público en salud per cápita para población con seguridad social',
#        'Gasto público en salud per cápita para población sin seguridad social ',
#        'Gasto público en salud per cápita total',
#        'Aportación federal al financiamiento de la salud de la población sin seguridad social (%)'],
#       dtype='object')

# %%
#Renombrar columnas: primer paso, crear mapa
column_name_mapping = {
    'Entidad Federativa' : 'Estado', 
    'Año' : 'Año',
       'Producto Interno Bruto                       (Miles de pesos)' : 'PIB en miles de pesos',
       'I.1 Gasto Público Total en Salud\n(Miles de pesos)\n(1 + 2)' : 'Total gasto público en salud',
       '1. Gasto Total \n(A+B+C+D+E+F) con SS' : 'Subtotal no asegurados',
       'A. Advo. Secretaria de Salud\n(Ramo 12)' : 'Gasto administrativo SSA', 
       'B. FASSA (Ramo 33)' : 'Aportaciones federales',
       'F. Gasto \nEstatal' : 'Gasto estatal en salud', 
       '2. Gasto Total\n(A+B+C+D+E) sin SS' : 'Subtotal asegurados', 
       'A. IMSS' : 'IMSS',
       'B. ISSSTE' : 'ISSSTE', 
       'B. Cuotas de Recuperación' : 'Cuotas de recuperación', 
       'C. Pago de Primas' : 'Primas de seguros médicos',
       'Gasto  público total en salud como % del PIB' : 'Total gasto en salud % PIB',
       'Gasto público total en salud como % del gasto público total' : 'Total gasto en salud % gasto público',
       'Gasto público en salud per cápita para población con seguridad social' : 'Gasto en salud asegurados per cápita',
       'Gasto público en salud per cápita para población sin seguridad social ' : 'Gasto en salud no asegurados per cápita',
       'Gasto público en salud per cápita total' : 'Total gasto en salud per cápita',
       'Aportación federal al financiamiento de la salud de la población sin seguridad social (%)' : 'Aportación federal % no asegurados'
}

# %%
#Renombrar columnas: segundo paso, rename
gasto_salud_rename = gasto_salud_drop.rename(columns=column_name_mapping)
gasto_salud_rename.head()
# Out:
#                        Estado        Año  PIB en miles de pesos  \
# 238  Estados Unidos Mexicanos 2000-01-01           1.098389e+10
# 239            Aguascalientes 2000-01-01           1.233635e+08
# 240           Baja California 2000-01-01           3.617749e+08
# 241       Baja California Sur 2000-01-01           5.392448e+07
# 242                  Campeche 2000-01-01           1.191197e+08
#
#      Total gasto público en salud  Subtotal no asegurados  \
# 238                  2.843230e+08             92221099.75
# 239                  3.028818e+06              1059039.52
# 240                  7.325541e+06              1142409.28
# 241                  2.110065e+06               548082.52
# 242                  2.428181e+06               984654.51
#
#      Gasto administrativo SSA  Aportaciones federales  Gasto estatal en salud  \
# 238               32524104.49             45666769.87             14030225.39
# 239                   6816.29               691829.84               360393.39
# 240                  58962.54              1035444.66                48002.07
# 241                   6526.28               519422.41                22133.83
# 242                 149975.07               697430.08               137249.36
#
#      Subtotal asegurados          IMSS       ISSSTE  Cuotas de recuperación  \
# 238         1.921019e+08  1.581991e+08  25106991.01                     0.0
# 239         1.969779e+06  1.791865e+06    167010.80                     0.0
# 240         6.183132e+06  5.730923e+06    418176.84                     0.0
# 241         1.561983e+06  1.237632e+06    317848.31                     0.0
# 242         1.443527e+06  9.289885e+05    161987.19                     0.0
#
#      Primas de seguros médicos  Total gasto en salud % PIB  \
# 238                15242292.93                         2.6
# 239                   49754.01                         2.5
# 240                  225017.87                         2.0
# 241                    5631.66                         3.9
# 242                    1734.41                         2.0
#
#      Total gasto en salud % gasto público  \
# 238                                  16.6
# 239                                  12.8
# 240                                  17.6
# 241                                  17.3
# 242                                   7.0
#
#      Gasto en salud asegurados per cápita  \
# 238                               3884.49
# 239                               3052.95
# 240                               3720.76
# 241                               4842.07
# 242                               4392.01
#
#      Gasto en salud no asegurados per cápita  Total gasto en salud per cápita  \
# 238                                  1792.72                          2817.98
# 239                                  2915.51                          3003.45
# 240                                  1286.42                          2872.94
# 241                                  3809.58                          4523.62
# 242                                  2646.65                          3465.33
#
#      Aportación federal % no asegurados
# 238                                84.8
# 239                                66.0
# 240                                95.8
# 241                                96.0
# 242                                86.1

# %%
#Cambiar índice a Multi-índice jerárquico tipo: Lugar, Año
gasto_salud_rename = gasto_salud_rename.set_index(['Estado', 'Año'])

# %%
#Revisar multi-índice, por ejemplo las filas correspondientes al total nacional con el índice 'Estados Unidos Mexicanos'
gasto_salud_rename.loc[('Estados Unidos Mexicanos' , )]
# Out:
# C:\Users\juanl\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: PerformanceWarning: indexing past lexsort depth may impact performance.
#             PIB en miles de pesos  Total gasto público en salud  \
# Año
# 2000-01-01           1.098389e+10                  2.843230e+08
# 2001-01-01           1.113015e+10                  2.973201e+08
# 2002-01-01           1.135181e+10                  3.065797e+08
# 2003-01-01           1.371616e+10                  3.413223e+08
# 2004-01-01           1.462950e+10                  3.874460e+08
# 2005-01-01           1.533560e+10                  3.965647e+08
# 2006-01-01           1.638521e+10                  4.159350e+08
# 2007-01-01           1.708843e+10                  4.480869e+08
# 2008-01-01           1.722585e+10                  4.727421e+08
# 2009-01-01           1.637483e+10                  5.046422e+08
# 2010-01-01           1.723685e+10                  5.321735e+08
# 2011-01-01           1.821639e+10                  5.543041e+08
# 2012-01-01           1.897029e+10                  5.922102e+08
# 2013-01-01           1.877588e+10                  6.048686e+08
# 2014-01-01           1.936610e+10                  5.805816e+08
# 2015-01-01           2.013161e+10                  6.195139e+08
# 2016-01-01           2.112051e+10                  6.214495e+08
# 2017-01-01           2.192124e+10                  6.229374e+08
#
#             Subtotal no asegurados  Gasto administrativo SSA  \
# Año
# 2000-01-01            9.222110e+07              3.252410e+07
# 2001-01-01            9.845457e+07              3.470172e+07
# 2002-01-01            1.039565e+08              3.648042e+07
# 2003-01-01            1.148265e+08              3.823256e+07
# 2004-01-01            1.283782e+08              3.926340e+07
# 2005-01-01            1.525284e+08              5.405342e+07
# 2006-01-01            1.677360e+08              6.403650e+07
# 2007-01-01            1.873456e+08              7.894143e+07
# 2008-01-01            2.143168e+08              9.724832e+07
# 2009-01-01            2.320006e+08              1.089961e+08
# 2010-01-01            2.410450e+08              1.118901e+08
# 2011-01-01            2.496195e+08              1.239715e+08
# 2012-01-01            2.657807e+08              1.352063e+08
# 2013-01-01            2.679963e+08              1.371452e+08
# 2014-01-01            2.703961e+08              1.339123e+08
# 2015-01-01            2.848573e+08              1.321445e+08
# 2016-01-01            2.850900e+08              1.305456e+08
# 2017-01-01            2.897093e+08              1.321862e+08
#
#             Aportaciones federales  Gasto estatal en salud  \
# Año
# 2000-01-01             45666769.87             14030225.39
# 2001-01-01             49370886.99             14381964.08
# 2002-01-01             49616910.18             17859211.05
# 2003-01-01             55152442.53             17840391.73
# 2004-01-01             57188030.78             20453576.63
# 2005-01-01             62001919.83             24164585.07
# 2006-01-01             64350496.44             26009530.14
# 2007-01-01             64616657.66             28720208.49
# 2008-01-01             67599729.43             34462002.07
# 2009-01-01             67876334.07             37681556.04
# 2010-01-01             66915746.97             43472950.32
# 2011-01-01             72633762.18             33163988.85
# 2012-01-01             77706631.03             30609281.56
# 2013-01-01             78068452.78             32549176.05
# 2014-01-01             81009431.05             35423953.58
# 2015-01-01             86892782.97             44921589.47
# 2016-01-01             89921564.45             43269704.01
# 2017-01-01             91775820.76             43651170.74
#
#             Subtotal asegurados          IMSS       ISSSTE  \
# Año
# 2000-01-01         1.921019e+08  1.581991e+08  25106991.01
# 2001-01-01         1.988655e+08  1.614671e+08  27498538.85
# 2002-01-01         2.026231e+08  1.649721e+08  27371161.63
# 2003-01-01         2.264958e+08  1.822556e+08  31137314.77
# 2004-01-01         2.590678e+08  2.148326e+08  31385215.25
# 2005-01-01         2.440363e+08  1.961833e+08  34047737.81
# 2006-01-01         2.481990e+08  1.983873e+08  35369161.31
# 2007-01-01         2.607413e+08  2.010516e+08  44433202.72
# 2008-01-01         2.584253e+08  1.977370e+08  44627324.68
# 2009-01-01         2.726417e+08  2.089210e+08  47360009.09
# 2010-01-01         2.911284e+08  2.242927e+08  50952257.48
# 2011-01-01         3.046847e+08  2.280182e+08  59732326.20
# 2012-01-01         3.264295e+08  2.393268e+08  55354498.62
# 2013-01-01         3.368723e+08  2.406063e+08  57482005.98
# 2014-01-01         3.101855e+08  2.212072e+08  52431231.57
# 2015-01-01         3.346566e+08  2.389843e+08  56984095.70
# 2016-01-01         3.363595e+08  2.409288e+08  55490077.52
# 2017-01-01         3.332281e+08  2.448560e+08  52176601.46
#
#             Cuotas de recuperación  Primas de seguros médicos  \
# Año
# 2000-01-01                    0.00                15242292.93
# 2001-01-01              4535439.68                18370934.32
# 2002-01-01              5294857.29                20225299.61
# 2003-01-01              6042391.22                22548726.44
# 2004-01-01              6001726.66                24818323.23
# 2005-01-01              6398953.09                28406546.92
# 2006-01-01              6902849.59                31588338.69
# 2007-01-01              8268915.24                36307108.86
# 2008-01-01              6379616.30                37398217.51
# 2009-01-01              6224138.39                40765663.78
# 2010-01-01              6955268.30                42220516.27
# 2011-01-01              6543731.78                44957779.47
# 2012-01-01              5861962.01                47355186.53
# 2013-01-01              6172450.10                48824091.32
# 2014-01-01              6528108.17                55050569.70
# 2015-01-01              6739376.83                56647093.46
# 2016-01-01              6128194.58                64418047.02
# 2017-01-01              6687835.37                66817416.14
#
#             Total gasto en salud % PIB  Total gasto en salud % gasto público  \
# Año
# 2000-01-01                         2.6                                  16.6
# 2001-01-01                         2.7                                  16.6
# 2002-01-01                         2.7                                  15.7
# 2003-01-01                         2.5                                  15.8
# 2004-01-01                         2.6                                  17.6
# 2005-01-01                         2.6                                  16.7
# 2006-01-01                         2.5                                  16.1
# 2007-01-01                         2.6                                  15.8
# 2008-01-01                         2.7                                  15.2
# 2009-01-01                         3.1                                  15.2
# 2010-01-01                         3.1                                  15.6
# 2011-01-01                         3.0                                  15.5
# 2012-01-01                         3.1                                  15.8
# 2013-01-01                         3.2                                  15.7
# 2014-01-01                         3.0                                  14.5
# 2015-01-01                         3.1                                  14.8
# 2016-01-01                         2.9                                  14.1
# 2017-01-01                         2.8                                  15.8
#
#             Gasto en salud asegurados per cápita  \
# Año
# 2000-01-01                               3884.49
# 2001-01-01                               4046.21
# 2002-01-01                               4145.60
# 2003-01-01                               4659.20
# 2004-01-01                               5361.76
# 2005-01-01                               5081.94
# 2006-01-01                               5102.53
# 2007-01-01                               5289.09
# 2008-01-01                               5139.98
# 2009-01-01                               5381.32
# 2010-01-01                               5698.77
# 2011-01-01                               5879.19
# 2012-01-01                               6212.48
# 2013-01-01                               6326.13
# 2014-01-01                               5749.72
# 2015-01-01                               6125.48
# 2016-01-01                               6081.53
# 2017-01-01                               5953.41
#
#             Gasto en salud no asegurados per cápita  \
# Año
# 2000-01-01                                  1792.72
# 2001-01-01                                  1858.57
# 2002-01-01                                  1906.02
# 2003-01-01                                  2046.55
# 2004-01-01                                  2227.48
# 2005-01-01                                  2579.51
# 2006-01-01                                  2806.52
# 2007-01-01                                  3097.16
# 2008-01-01                                  3512.15
# 2009-01-01                                  3730.63
# 2010-01-01                                  3815.85
# 2011-01-01                                  3908.94
# 2012-01-01                                  4120.02
# 2013-01-01                                  4113.90
# 2014-01-01                                  4111.53
# 2015-01-01                                  4291.81
# 2016-01-01                                  4257.29
# 2017-01-01                                  4289.09
#
#             Total gasto en salud per cápita  \
# Año
# 2000-01-01                          2817.98
# 2001-01-01                          2911.41
# 2002-01-01                          2964.47
# 2003-01-01                          3259.38
# 2004-01-01                          3656.82
# 2005-01-01                          3700.99
# 2006-01-01                          3836.73
# 2007-01-01                          4081.41
# 2008-01-01                          4247.50
# 2009-01-01                          4471.69
# 2010-01-01                          4862.69
# 2011-01-01                          4791.58
# 2012-01-01                          5059.30
# 2013-01-01                          5108.90
# 2014-01-01                          4849.77
# 2015-01-01                          5119.70
# 2016-01-01                          5082.46
# 2017-01-01                          5043.28
#
#             Aportación federal % no asegurados
# Año
# 2000-01-01                                84.8
# 2001-01-01                                85.4
# 2002-01-01                                82.8
# 2003-01-01                                84.5
# 2004-01-01                                84.1
# 2005-01-01                                84.2
# 2006-01-01                                84.5
# 2007-01-01                                84.7
# 2008-01-01                                83.9
# 2009-01-01                                83.8
# 2010-01-01                                82.0
# 2011-01-01                                86.7
# 2012-01-01                                88.5
# 2013-01-01                                87.9
# 2014-01-01                                86.9
# 2015-01-01                                84.2
# 2016-01-01                                84.8
# 2017-01-01                                84.9

# %% [markdown]
# ##### **III. Procesamiento y exploración de datos**

# %%
## III. Análisis exploratorio de datos
import statistics
gasto_salud_rename.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 594 entries, ('Estados Unidos Mexicanos', Timestamp('2000-01-01 00:00:00')) to ('Zacatecas', Timestamp('2017-01-01 00:00:00'))
# Data columns (total 17 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   PIB en miles de pesos                    594 non-null    float64
#  1   Total gasto público en salud             594 non-null    float64
#  2   Subtotal no asegurados                   594 non-null    float64
#  3   Gasto administrativo SSA                 594 non-null    float64
#  4   Aportaciones federales                   594 non-null    float64
#  5   Gasto estatal en salud                   594 non-null    float64
#  6   Subtotal asegurados                      594 non-null    float64
#  7   IMSS                                     594 non-null    float64
#  8   ISSSTE                                   594 non-null    float64
#  9   Cuotas de recuperación                   594 non-null    float64
#  10  Primas de seguros médicos                594 non-null    float64
#  11  Total gasto en salud % PIB               594 non-null    float64
#  12  Total gasto en salud % gasto público     594 non-null    float64
#  13  Gasto en salud asegurados per cápita     594 non-null    float64
#  14  Gasto en salud no asegurados per cápita  594 non-null    float64
#  15  Total gasto en salud per cápita          594 non-null    float64
#  16  Aportación federal % no asegurados       594 non-null    float64
# dtypes: float64(17)
# memory usage: 102.5+ KB

# %%
#Estadística descriptiva
gasto_salud_rename.sum()
# Out:
# PIB en miles de pesos                      5.852176e+11
# Total gasto público en salud               1.702426e+10
# Subtotal no asegurados                     7.184743e+09
# Gasto administrativo SSA                   3.242959e+09
# Aportaciones federales                     2.456729e+09
# Gasto estatal en salud                     1.085330e+09
# Subtotal asegurados                        9.839522e+09
# IMSS                                       7.524454e+09
# ISSSTE                                     1.577880e+09
# Cuotas de recuperación                     1.681384e+08
# Primas de seguros médicos                  1.402496e+09
# Total gasto en salud % PIB                 1.883400e+03
# Total gasto en salud % gasto público       1.179710e+04
# Gasto en salud asegurados per cápita       2.904170e+06
# Gasto en salud no asegurados per cápita    2.062957e+06
# Total gasto en salud per cápita            2.453217e+06
# Aportación federal % no asegurados         5.168900e+04
# dtype: float64

# %%
#Minimo
gasto_salud_rename.min()
# Out:
# PIB en miles de pesos                      52760381.86
# Total gasto público en salud                1785581.58
# Subtotal no asegurados                       548082.52
# Gasto administrativo SSA                       6526.28
# Aportaciones federales                       519422.41
# Gasto estatal en salud                            0.00
# Subtotal asegurados                         1082969.91
# IMSS                                         928988.47
# ISSSTE                                        54624.00
# Cuotas de recuperación                            0.00
# Primas de seguros médicos                      1442.60
# Total gasto en salud % PIB                        0.50
# Total gasto en salud % gasto público              2.60
# Gasto en salud asegurados per cápita           1865.68
# Gasto en salud no asegurados per cápita         750.89
# Total gasto en salud per cápita                1399.18
# Aportación federal % no asegurados               44.60
# dtype: float64

# %%
#Máximo
gasto_salud_rename.max()
# Out:
# PIB en miles de pesos                      2.192124e+10
# Total gasto público en salud               6.229374e+08
# Subtotal no asegurados                     2.897093e+08
# Gasto administrativo SSA                   1.371452e+08
# Aportaciones federales                     9.177582e+07
# Gasto estatal en salud                     4.492159e+07
# Subtotal asegurados                        3.368723e+08
# IMSS                                       2.448560e+08
# ISSSTE                                     5.973233e+07
# Cuotas de recuperación                     8.268915e+06
# Primas de seguros médicos                  6.681742e+07
# Total gasto en salud % PIB                 5.800000e+00
# Total gasto en salud % gasto público       4.120000e+01
# Gasto en salud asegurados per cápita       1.793227e+04
# Gasto en salud no asegurados per cápita    8.868080e+03
# Total gasto en salud per cápita            1.364111e+04
# Aportación federal % no asegurados         1.000000e+02
# dtype: float64

# %%
#Estadística descriptiva
gasto_salud_rename.describe().loc[["mean", "std"]].T
# Out:
#                                                  mean           std
# PIB en miles de pesos                    9.852149e+08  2.878697e+09
# Total gasto público en salud             2.866038e+07  8.369640e+07
# Subtotal no asegurados                   1.209553e+07  3.641248e+07
# Gasto administrativo SSA                 5.459527e+06  1.700043e+07
# Aportaciones federales                   4.135907e+06  1.167157e+07
# Gasto estatal en salud                   1.827155e+06  5.536310e+06
# Subtotal asegurados                      1.656485e+07  4.791421e+07
# IMSS                                     1.266743e+07  3.601873e+07
# ISSSTE                                   2.656363e+06  8.350653e+06
# Cuotas de recuperación                   2.830613e+05  1.054172e+06
# Primas de seguros médicos                2.361104e+06  7.724483e+06
# Total gasto en salud % PIB               3.170707e+00  9.597378e-01
# Total gasto en salud % gasto público     1.986044e+01  6.128720e+00
# Gasto en salud asegurados per cápita     4.889175e+03  1.916783e+03
# Gasto en salud no asegurados per cápita  3.472992e+03  1.430361e+03
# Total gasto en salud per cápita          4.129996e+03  1.633400e+03
# Aportación federal % no asegurados       8.701852e+01  9.849022e+00

# %%
gasto_salud_por_estado = gasto_salud_rename.groupby('Estado')['Total gasto público en salud'].agg(pd.Series.mean)
gasto_salud_por_estado.head()
# Out:
# Estado
# Aguascalientes         5.303104e+06
# Baja California        1.298864e+07
# Baja California Sur    3.841075e+06
# Campeche               4.683529e+06
# Chiapas                1.330503e+07
# Name: Total gasto público en salud, dtype: float64

# %%
#Visualización
gasto_salud_por_estado.plot(kind='bar', subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fdfc7cb8b10>],
#       dtype=object)

# %% [markdown]
# #### **Dataset 2:**
# Mortalidad cáncer de mama, México
# - Observaciones: Estados de la República
# - Periodo: 2000-2015
# - Archivo: "MortalidadCaMa2000a2015.csv"
# - Fuente: Dirección General de Información en Salud (DGIS) Secretaría de Salud (SSA)
# - Descripción: Defunciones de mujeres de 25 años y más por tumor maligno de mama (C50), 2000-2015

# %% [markdown]
# ##### **I. Carga de datos**

# %%
### SEGUNDO DATASET: 
## I.Cargar datos en formato csv
#NOTA: Archivo en  latin-1
mortalidad = pd.read_csv("https://raw.githubusercontent.com/Zoe-Garcia/Equipo_2_P2/main/DATA/SSA%20Mexico/MortalidadCaMa2000a2015.csv", sep=',', encoding='latin-1')
mortalidad.head()
# Out:
#   Entidad de Residencia  num_2000  tasa_2000  ...  tasa_2014  num_2015  tasa_2015
# 0              Nacional      3419       14.1  ...       17.6      6252       18.0
# 1        Aguascalientes        36       15.6  ...       19.2        71       20.2
# 2       Baja California        98       16.7  ...       19.9       213       22.0
# 3   Baja California Sur        20       19.1  ...       15.6        33       16.0
# 4              Campeche        10        6.3  ...        6.8        29       11.4
#
# [5 rows x 33 columns]

# %% [markdown]
# ##### **II. Limpieza de datos**

# %%
##. II.Conocer DDBB y limpiarla
#Conocer tipo de datos y características generales del DataFrame
mortalidad.shape
# Out:
# (33, 33)

# %%
#Tipo de datos
mortalidad.dtypes
#Nota: Los datos son numéricos
# Out:
# Entidad de Residencia     object
# num_2000                   int64
# tasa_2000                float64
# num_2001                   int64
# tasa_2001                float64
# num_2002                   int64
# tasa_2002                float64
# num_2003                   int64
# tasa_2003                float64
# num_2004                   int64
# tasa_2004                float64
# num_2005                   int64
# tasa_2005                float64
# num_2006                   int64
# tasa_2006                float64
# num_2007                   int64
# tasa_2007                float64
# num_2008                   int64
# tasa_2008                float64
# num_2009                   int64
# tasa_2009                float64
# num_2010                   int64
# tasa_2010                float64
# num_2011                   int64
# tasa_2011                float64
# num_2012                   int64
# tasa_2012                float64
# num_2013                   int64
# tasa_2013                float64
# num_2014                   int64
# tasa_2014                float64
# num_2015                   int64
# tasa_2015                float64
# dtype: object

# %%
#Información de DataFrame
mortalidad.info
# Out:
# <bound method DataFrame.info of    Entidad de Residencia  num_2000  tasa_2000  ...  tasa_2014  num_2015  tasa_2015
# 0               Nacional      3419       14.1  ...       17.6      6252       18.0
# 1         Aguascalientes        36       15.6  ...       19.2        71       20.2
# 2        Baja California        98       16.7  ...       19.9       213       22.0
# 3    Baja California Sur        20       19.1  ...       15.6        33       16.0
# 4               Campeche        10        6.3  ...        6.8        29       11.4
# 5   Coahuila de Zaragoza       114       19.7  ...       21.3       215       25.7
# 6                 Colima        17       12.8  ...       24.1        46       22.0
# 7                Chiapas        53        6.3  ...       12.2       142       10.8
# 8              Chihuahua       152       20.9  ...       29.9       261       24.8
# 9       Distrito Federal       575       22.2  ...       24.0       739       24.7
# 10               Durango        48       14.0  ...       17.9        92       18.9
# 11            Guanajuato       123       10.6  ...       17.4       277       17.0
# 12              Guerrero        58        8.1  ...       12.5       118       12.5
# 13               Hidalgo        61       10.7  ...       12.1       119       14.3
# 14               Jalisco       290       18.6  ...       21.8       495       22.0
# 15                México       368       11.8  ...       14.9       743       15.2
# 16   Michoacán de Ocampo       126       13.1  ...       16.4       215       16.5
# 17               Morelos        39        9.8  ...       13.0        98       17.1
# 18               Nayarit        36       16.3  ...       17.6        45       13.3
# 19            Nuevo León       214       21.8  ...       25.6       386       26.0
# 20                Oaxaca        65        7.5  ...       10.0       125       11.1
# 21                Puebla       117        9.6  ...       13.1       217       12.6
# 22  Querétaro de Arteaga        35        9.9  ...       19.2        80       14.1
# 23          Quintana Roo        14        7.4  ...        9.7        59       14.1
# 24       San Luis Potosí        56       10.1  ...       15.9       114       14.9
# 25               Sinaloa        93       15.4  ...       17.7       189       22.2
# 26                Sonora       109       19.8  ...       22.6       233       28.6
# 27               Tabasco        39        8.9  ...       12.3        98       14.7
# 28            Tamaulipas       122       17.5  ...       20.5       214       20.7
# 29              Tlaxcala        15        6.4  ...       12.0        42       11.7
# 30        Veracruz Llave       220       12.2  ...       15.7       375       15.7
# 31               Yucatán        52       12.6  ...       14.7        81       13.2
# 32             Zacatecas        44       13.5  ...       18.0        88       20.0
#
# [33 rows x 33 columns]>

# %%
#Contar los NaN por columna
mortalidad.isna().sum(axis=0)
#Nota: Este DataFrame no tiene datos nulos
# Out:
# Entidad de Residencia    0
# num_2000                 0
# tasa_2000                0
# num_2001                 0
# tasa_2001                0
# num_2002                 0
# tasa_2002                0
# num_2003                 0
# tasa_2003                0
# num_2004                 0
# tasa_2004                0
# num_2005                 0
# tasa_2005                0
# num_2006                 0
# tasa_2006                0
# num_2007                 0
# tasa_2007                0
# num_2008                 0
# tasa_2008                0
# num_2009                 0
# tasa_2009                0
# num_2010                 0
# tasa_2010                0
# num_2011                 0
# tasa_2011                0
# num_2012                 0
# tasa_2012                0
# num_2013                 0
# tasa_2013                0
# num_2014                 0
# tasa_2014                0
# num_2015                 0
# tasa_2015                0
# dtype: int64

# %%
#Cambiar nombre
mortalidad_rename = mortalidad.rename(columns={'Entidad de Residencia' : 'Estado'})
mortalidad_rename.head()
# Out:
#                 Estado  num_2000  tasa_2000  ...  tasa_2014  num_2015  tasa_2015
# 0             Nacional      3419       14.1  ...       17.6      6252       18.0
# 1       Aguascalientes        36       15.6  ...       19.2        71       20.2
# 2      Baja California        98       16.7  ...       19.9       213       22.0
# 3  Baja California Sur        20       19.1  ...       15.6        33       16.0
# 4             Campeche        10        6.3  ...        6.8        29       11.4
#
# [5 rows x 33 columns]

# %%
#Cambiar índice a 'Entidad de Residencia'
mortalidad_rename = mortalidad_rename.set_index(['Estado'])

# %%
#Revisar cambio
mortalidad_rename.head()
# Out:
#                      num_2000  tasa_2000  ...  num_2015  tasa_2015
# Estado                                    ...
# Nacional                 3419       14.1  ...      6252       18.0
# Aguascalientes             36       15.6  ...        71       20.2
# Baja California            98       16.7  ...       213       22.0
# Baja California Sur        20       19.1  ...        33       16.0
# Campeche                   10        6.3  ...        29       11.4
#
# [5 rows x 32 columns]

# %% [markdown]
# ##### **III. Procesamiento y exploración**

# %%
## III. Análisis exploratorio de datos
mortalidad_rename.sum(axis=1)
# Out:
# Estado
# Nacional                75443.9
# Aguascalientes           1080.7
# Baja California          2628.0
# Baja California Sur       783.9
# Campeche                  480.2
# Coahuila de Zaragoza     2721.3
# Colima                    852.3
# Chiapas                  1792.7
# Chihuahua                3534.1
# Distrito Federal        10478.6
# Durango                  1238.9
# Guanajuato               3476.4
# Guerrero                 1556.8
# Hidalgo                  1529.2
# Jalisco                  6623.2
# México                   9201.9
# Michoacán de Ocampo      2891.9
# Morelos                  1399.7
# Nayarit                   901.0
# Nuevo León               4636.0
# Oaxaca                   1553.5
# Puebla                   2982.1
# Querétaro de Arteaga     1321.5
# Quintana Roo              531.5
# San Luis Potosí          1678.7
# Sinaloa                  2329.2
# Sonora                   2653.0
# Tabasco                  1186.1
# Tamaulipas               2990.0
# Tlaxcala                  715.9
# Veracruz Llave           4969.2
# Yucatán                  1130.7
# Zacatecas                1174.2
# dtype: float64

# %%
#Máximo
mortalidad_rename.max(axis=1)
# Out:
# Estado
# Nacional                6252.0
# Aguascalientes            71.0
# Baja California          213.0
# Baja California Sur       39.0
# Campeche                  30.0
# Coahuila de Zaragoza     215.0
# Colima                    49.0
# Chiapas                  157.0
# Chihuahua                308.0
# Distrito Federal         739.0
# Durango                   92.0
# Guanajuato               277.0
# Guerrero                 118.0
# Hidalgo                  119.0
# Jalisco                  495.0
# México                   743.0
# Michoacán de Ocampo      215.0
# Morelos                  105.0
# Nayarit                   58.0
# Nuevo León               386.0
# Oaxaca                   125.0
# Puebla                   227.0
# Querétaro de Arteaga     106.0
# Quintana Roo              59.0
# San Luis Potosí          119.0
# Sinaloa                  189.0
# Sonora                   233.0
# Tabasco                   98.0
# Tamaulipas               214.0
# Tlaxcala                  45.0
# Veracruz Llave           383.0
# Yucatán                   88.0
# Zacatecas                 88.0
# dtype: float64

# %%
#Mínimo
mortalidad_rename.min(axis=1)
# Out:
# Estado
# Nacional                14.1
# Aguascalientes          13.0
# Baja California         15.7
# Baja California Sur     15.6
# Campeche                 6.3
# Coahuila de Zaragoza    16.9
# Colima                  12.8
# Chiapas                  6.2
# Chihuahua               18.6
# Distrito Federal        19.3
# Durango                 11.9
# Guanajuato              10.6
# Guerrero                 8.1
# Hidalgo                 10.2
# Jalisco                 17.5
# México                  11.8
# Michoacán de Ocampo     11.9
# Morelos                  9.8
# Nayarit                 11.9
# Nuevo León              17.1
# Oaxaca                   7.2
# Puebla                   9.6
# Querétaro de Arteaga     9.9
# Quintana Roo             3.9
# San Luis Potosí          8.9
# Sinaloa                 12.4
# Sonora                  17.6
# Tabasco                  7.9
# Tamaulipas              16.2
# Tlaxcala                 6.4
# Veracruz Llave          11.7
# Yucatán                  7.2
# Zacatecas               10.7
# dtype: float64

# %%
#Estadística descriptiva
mortalidad_rename.describe().loc[["mean", "std"]].T
# Out:
#                  mean          std
# num_2000   207.212121   588.299178
# tasa_2000   13.312121     4.775311
# num_2001   215.939394   612.902569
# tasa_2001   13.469697     3.974960
# num_2002   231.636364   656.996900
# tasa_2002   14.257576     4.582373
# num_2003   234.000000   663.530472
# tasa_2003   14.087879     4.371696
# num_2004   251.515152   712.379951
# tasa_2004   14.666667     4.147414
# num_2005   254.848485   722.565962
# tasa_2005   14.506061     4.614240
# num_2006   269.090909   761.628944
# tasa_2006   15.172727     4.413422
# num_2007   277.636364   784.986816
# tasa_2007   15.493939     4.724401
# num_2008   291.030303   823.587066
# tasa_2008   15.551515     4.881926
# num_2009   296.545455   838.350765
# tasa_2009   15.554545     4.217974
# num_2010   305.090909   862.682639
# tasa_2010   15.581818     4.202935
# num_2011   315.515152   892.040888
# tasa_2011   15.784848     4.581902
# num_2012   338.363636   955.099760
# tasa_2012   16.866667     4.394362
# num_2013   327.575758   923.376854
# tasa_2013   16.090909     4.142641
# num_2014   362.060606  1022.350201
# tasa_2014   17.006061     5.040582
# num_2015   378.909091  1069.310653
# tasa_2015   17.636364     4.930886

# %%
#Visualización
mortalidad_rename.plot(kind='box', subplots=False)

# %% [markdown]
# ###**Bases de datos:**
# DGIS (9 de mayo de 2019). “Gasto en Salud, 1993-2017 (miles de pesos constantes, 2017=100)”, Dirección General de Información en Salud (DGIS) Secretaría de Salud (SSA), México. Recuperado de: http://www.dgis.salud.gob.mx/descargas/xls/1._GFF_01_2017_A_CONS_O.xlsx
#
# DGIS (2 de diciembre de 2016). "Defunciones de mujeres de 25 años y más por tumor maligno de mama (C50), 2000-2015", Dirección General de Información en Salud (DGIS) Secretaría de Salud (SSA), México. Recuperado de: https://www.gob.mx/cms/uploads/attachment/file/269549/MortalidadCaMa2000a2015.pdf

# %% [markdown]
# ### **Pregunta de investigación 3**
# #### **2. ¿Qué factores influyen en la incidencia del cáncer de mama en mujeres?**
#
# En esta sección indagaremos en los resultados obtenidos en mastografías realizadas en 2019, con el fin de comprobar si la edad de una mujer tiene incidencia en el desarrollo de cáncer de mama

# %%
#Importacion de paquetes
import pandas as pd

# %% [markdown]
#  Dataset 1:
#
# Resultados de Mastografías en México en 2019

# %%
#carga de datos 
mastografias_2019 = pd.read_csv("/Mastografías 2019.csv",sep=",",encoding="latin-1",header=1)

# %%
mastografias_2019.head(5)
# Out:
#    Clave Entidad         Entidad  ...  Fecha Interpretación Masto Resultado
# 0            1.0  Aguascalientes  ...                  04/11/2019   Benigna
# 1            1.0  Aguascalientes  ...                  03/11/2019   Benigna
# 2            1.0  Aguascalientes  ...                  04/11/2019   Benigna
# 3            1.0  Aguascalientes  ...                  03/11/2019   Benigna
# 4            1.0  Aguascalientes  ...                  09/11/2019   Benigna
#
# [5 rows x 10 columns]

# %%
#Solo se seleccionan las columnas para el analisis
mastografias_2019_copia = mastografias_2019.copy()
mastografias_2019_copia = mastografias_2019_copia[["Edad","Fecha Interpretación Masto","Resultado"]]

# %%
#Se buscan diferentes edades que existen en el df
mastografias_2019_copia['Edad'].unique()
# Out:
# array([45., 55., 61., 60., 52., 59., 56., 66., 53., 47., 50., 62., 51.,
#        42., 46., 41., 65., 57., 43., 58., 54., 48., 68., 67., 44., 64.,
#        40., 49., 69., 38., 37., 63., 32., 33., 35., 39., 36., 34., 28.,
#        30., 27., 29., 31., 26., 25., nan])

# %%
#se busca si existen valores NaN
mastografias_2019_copia.isna().sum(axis=0)
# Out:
# Edad                          26186
# Fecha Interpretación Masto    26186
# Resultado                     26186
# dtype: int64

# %%
#Eliminaciond valores NaN
mastografias_2019_copia = mastografias_2019_copia.dropna(axis=0)

# %%
# Comprobacion de que se eliminaron los datos NaN
print(mastografias_2019_copia.isna().sum(axis=0))
print(mastografias_2019.shape)
print(mastografias_2019_copia.shape)
# Out:
# (816904, 10)
# (790718, 3)

# %%
# Se buscan los diferentes tipos de resultados que se obtuvieron
mastografias_2019_copia['Resultado'].unique()
# Out:
# array(['Benigna', 'Negativa', 'Riesgo Moderado de Malignidad',
#        'Anormalidad Sospechosa', 'Riesgo Intermedio de Malignidad',
#        'Altamente Sugestiva a Malignidad', 'Probablemente Benigna',
#        'Evaluación Adicional', 'Baja Sospecha de Malignidad'],
#       dtype=object)

# %%
#Se realiza conteo de registros por resultado y edad
agrupacion_resultado = mastografias_2019_copia.groupby(["Resultado","Edad"])[["Edad"]].agg("count")
agrupacion_resultado
# Out:
#                                        Edad
# Resultado                        Edad
# Altamente Sugestiva a Malignidad 26.0     1
#                                  27.0     1
#                                  28.0     1
#                                  30.0     2
#                                  31.0     3
# ...                                     ...
# Riesgo Moderado de Malignidad    65.0    10
#                                  66.0     7
#                                  67.0     6
#                                  68.0     5
#                                  69.0     6
#
# [385 rows x 1 columns]

# %%
#Promedio, mediana y desviación estandar de edad por cada tipo de resultado
print(mastografias_2019_copia.groupby(["Resultado"])[["Edad"]].agg(['mean', 'median', 'std']))
#Suma de registros por cada tipo de resultado
print(mastografias_2019_copia.groupby(["Resultado"])[["Edad"]].count().sort_values(by="Edad"))
# Out:
#                                        Edad
#                                        mean median       std
# Resultado
# Altamente Sugestiva a Malignidad  52.808333   53.0  8.625744
# Anormalidad Sospechosa            50.874771   50.0  7.833224
# Baja Sospecha de Malignidad       50.168142   49.0  7.786495
# Benigna                           51.823739   51.0  7.608225
# Evaluación Adicional              49.026600   48.0  6.974052
# Negativa                          50.781357   50.0  7.294853
# Probablemente Benigna             50.198712   49.0  7.381009
# Riesgo Intermedio de Malignidad   50.969422   50.0  8.209983
# Riesgo Moderado de Malignidad     51.384817   50.0  8.707018
#                                     Edad
# Resultado
# Riesgo Moderado de Malignidad        382
# Riesgo Intermedio de Malignidad      883
# Baja Sospecha de Malignidad          904
# Altamente Sugestiva a Malignidad    1080
# Anormalidad Sospechosa              2731
# Probablemente Benigna              15067
# Evaluación Adicional               53459
# Negativa                          108579
# Benigna                           607633

# %% [markdown]
# ## Resultado Benigno

# %%
#Top10 de edades donde el resultado de la mastografía fue Benigno. 
agrupacion_resultado.columns =["Conteo"]
print("\n10 primeras edades donde el resultado es Benigno")
print(agrupacion_resultado.loc["Benigna"].sort_values(by="Conteo",ascending =False).head(10))
print("\n10 ultimas edades donde el resultado es Benigno")
print(agrupacion_resultado.loc["Benigna"].sort_values(by="Conteo",ascending =False).tail(10))
# Out:
# 10 primeras edades donde el resultado es Benigno
#       Conteo
# Edad
# 45.0   28904
# 47.0   28810
# 46.0   28748
# 44.0   28253
# 48.0   27622
# 50.0   27366
# 49.0   27185
# 43.0   26936
# 51.0   26243
# 52.0   25498
#
# 10 ultimas edades donde el resultado es Benigno
#       Conteo
# Edad
# 34.0      97
# 33.0      49
# 32.0      44
# 31.0      39
# 30.0      27
# 29.0      22
# 28.0      22
# 27.0      12
# 25.0      10
# 26.0       8

# %%
# Analisis solo con mujeres mayores de 40 años
solo_mayores_40 = mastografias_2019_copia[mastografias_2019_copia["Edad"]>=40]
solo_mayores_40 = solo_mayores_40.groupby(["Resultado"])[["Edad"]].agg("count")
print(solo_mayores_40)
print("\nPorcentaje de resultado Bedigno: ")
print(((solo_mayores_40.loc["Benigna"].sum())/(agrupacion_resultado.loc[["Benigna"]].sum()))*100)
# Out:
#                                     Edad
# Resultado
# Altamente Sugestiva a Malignidad    1024
# Anormalidad Sospechosa              2666
# Baja Sospecha de Malignidad          871
# Benigna                           605352
# Evaluación Adicional               52811
# Negativa                          108100
# Probablemente Benigna              14899
# Riesgo Intermedio de Malignidad      852
# Riesgo Moderado de Malignidad        353
#
# Porcentaje de resultado Bedigno:
# Conteo    99.624609
# dtype: float64

# %% [markdown]
# ## Resultado entre intermedio y alto de Malignidad

# %%
solo_mayores_40 = mastografias_2019_copia[mastografias_2019_copia["Edad"]>=40]
solo_mayores_40 = solo_mayores_40.groupby(["Resultado"])[["Edad"]].agg("count")
(solo_mayores_40.loc["Altamente Sugestiva a Malignidad"].sum())/(agrupacion_resultado.loc[["Altamente Sugestiva a Malignidad","Riesgo Intermedio de Malignidad"]].sum())
# Out:
# Conteo    0.521651
# dtype: float64

# %%
#Top10 de edades donde el resultado de la mastografía fue Negativa. 
print("\n10 primeras edades donde se obtuvo como resultado un riesgo entre intermedio y alto de Malignidad")
print(agrupacion_resultado.loc[["Altamente Sugestiva a Malignidad","Riesgo Intermedio de Malignidad"]].sort_values(by ="Conteo",ascending =False).head(10))
print("\n10 ultimas edades donde se obtuvo como resultado un riesgo entre intermedio y alto de Malignidad")
print(agrupacion_resultado.loc[["Altamente Sugestiva a Malignidad","Riesgo Intermedio de Malignidad"]].sort_values(by="Conteo",ascending =False).tail(10))
# Out:
# 10 primeras edades donde se obtuvo como resultado un riesgo entre intermedio y alto de Malignidad
#                                        Conteo
# Resultado                        Edad
# Riesgo Intermedio de Malignidad  47.0      54
# Altamente Sugestiva a Malignidad 45.0      52
#                                  54.0      46
# Riesgo Intermedio de Malignidad  42.0      46
# Altamente Sugestiva a Malignidad 53.0      45
#                                  61.0      44
#                                  55.0      44
#                                  46.0      44
# Riesgo Intermedio de Malignidad  48.0      42
# Altamente Sugestiva a Malignidad 57.0      42
#
# 10 ultimas edades donde se obtuvo como resultado un riesgo entre intermedio y alto de Malignidad
#                                        Conteo
# Resultado                        Edad
# Riesgo Intermedio de Malignidad  31.0       2
#                                  29.0       2
# Altamente Sugestiva a Malignidad 30.0       2
#                                  34.0       2
#                                  33.0       2
#                                  28.0       1
#                                  27.0       1
# Riesgo Intermedio de Malignidad  25.0       1
#                                  36.0       1
# Altamente Sugestiva a Malignidad 26.0       1

# %% [markdown]
# ### Analisis sin resultados Benignos

# %%
sin_benignos = mastografias_2019_copia[mastografias_2019_copia["Resultado"]!="Benigna"]
#agrupacion
sin_benignos = sin_benignos.groupby(["Resultado"])[["Edad"]].agg("count")
print(sin_benignos)
print("\nPorcentaje de resultado Bedigno: ")
print(((sin_benignos.loc["Altamente Sugestiva a Malignidad"])/(sin_benignos["Edad"].sum()))*100)
print(((sin_benignos.loc["Riesgo Intermedio de Malignidad"])/(sin_benignos["Edad"].sum()))*100)
# Out:
#                                     Edad
# Resultado
# Altamente Sugestiva a Malignidad    1080
# Anormalidad Sospechosa              2731
# Baja Sospecha de Malignidad          904
# Evaluación Adicional               53459
# Negativa                          108579
# Probablemente Benigna              15067
# Riesgo Intermedio de Malignidad      883
# Riesgo Moderado de Malignidad        382
#
# Porcentaje de resultado Bedigno:
# Edad    0.58989
# Name: Altamente Sugestiva a Malignidad, dtype: float64
# Edad    0.48229
# Name: Riesgo Intermedio de Malignidad, dtype: float64

# %% [markdown]
# ### Conclusion pregunta 3
# Se puede observar que una gran parte de las personas que se realizaron una mastografía obtuvieron un resultado "Benigno", por otro lado, fijandonos en los resultados "Malignos" estos ocupan un porcentaje minimo en la muestra total, sin embargo se lográ apreciar que las mujeres mayores de 40 años son las más propensas a tener un resultado Maligno.

# %% [markdown]
# ### **Bases de datos:**
# Datos del Centro Nacional de Equidad de Género y Salud Reproductiva:
#  https://datos.gob.mx/busca/dataset/cancer-de-la-mujer-sicam-cancer-de-mama

# %% [markdown]
# ## **Hipótesis:**
#
# #### **¿Está México consciente de la problemática que trae consigo este problema de salud?**

# %% [markdown]
# ### Para responder esta pregunta se tienen dos datasets que contienen informaciónk acerca de la divulgación o atención que se le da al tema

# %% [markdown]
# ### comenzando por los datos de google trends:

# %%
import matplotlib.pyplot as plt

interes_time = pd.read_csv('interes_cancer_de_mama_tema.csv', header = 1)
interes_time
# Out:
#         Mes  Cáncer de mama: (México)
# 0   2012-01                        17
# 1   2012-02                        19
# 2   2012-03                        22
# 3   2012-04                        16
# 4   2012-05                        21
# ..      ...                       ...
# 92  2019-09                        31
# 93  2019-10                        97
# 94  2019-11                        32
# 95  2019-12                        19
# 96  2020-01                        20
#
# [97 rows x 2 columns]

# %%
list(interes_time)
# Out:
# ['Mes', 'Cáncer de mama: (México)']

# %%
#renombro las columnas:

nombres = {
    'Mes': 'fecha',
    'Cáncer de mama: (México)':'interes_en_cancer'
}

interes_time = interes_time.rename(columns = nombres)

#cambio el tipo de dato 'mes', por uno fecha:
interes_time['fecha'] = pd.to_datetime(interes_time['fecha'])

plt.plot(interes_time['fecha'], interes_time['interes_en_cancer'])

# %% [markdown]
# ##### Así, el data set nos dice que la atención que se le ha dado al tema ha aumentado desde el 2012. Aun así, la atención que la población en general tiene acerca del problema no ha cambiado en los últimos años, lo que puede notarse con respecto al umento del índice de morbilidad, por ejemplo, ya que una alta atención en el tema implicaría que la población tiene conocimiento acerca de la prevención de esta enfermedad, por ejemplo.

# %% [markdown]
# ### Ahora pasoa analizar los datos recopilados mediante WebScrapping:

# %% [markdown]
# ### primero pondré aquí el código que usé para realizar el scrapping:

# %% [markdown]
# ```Python
# from selenium import webdriver
# import time
# import numpy as np
# from numpy import random
#
# #despliego el navegador
# options = webdriver.ChromeOptions()
# options.add_argument('--disable-extensions')
#
# PATH = "C:\Program Files (x86)\chromedriver.exe"
#
# driver = webdriver.Chrome(PATH)
# url = 'https://www.google.com/search?q=cáncer+de+mama&lr=&cr=countryMX&hl=es&as_qdr=all&tbs=ctr:countryMX,cdr:1,cd_min:1/1/2013,cd_max:12/31/2013&sxsrf=ALeKk02jBq5CdA22tqCvC5cfnr1OMU7hmQ:1615318039798&filter=0&biw=1536&bih=723'
# driver.get(url)
#
# #formo todo en un webscrapper sobre google results:
#
# f = open('google_cancer_mama_2013.csv', 'w')
#
# f.write(('titulo, link, fecha' +'\n'))
# c = []
#
# a = False
#
# for i in range(0,99):
#
#     for element in driver.find_elements_by_xpath('//div[@class="g"]'):
#
#         titulo = element.find_element_by_xpath('.//h3').text
#         c += element.find_elements_by_xpath('.//span[@class = "f"]')
#
#         if len(c)>0:
#             fecha = c[0].text
#         else:
#             fecha = str(np.nan)
#
#         c = []
#         link = element.find_element_by_xpath('.//div[@class = "yuRUbf"]/a').get_attribute('href')
#         f.write(titulo.replace(',','|') +','+link.replace(',','|')+','+fecha.replace(',','|')+'\n')
#
#         a = random.choice([True, False, False])
#         t = random.choice([5,6,9,7,8,10,12,15,20,25,22,13,])
#
#     print(f'vamos en la página: {i+1}. Los segundos de espera son: {t}')
#     #hago un mini intento de "engañar" el motor de búsqueda de google:
#     if a == True:
#         time.sleep(t)
#     else:
#         time.sleep(t)
#
#     Next_Google_page = driver.find_element_by_link_text("Siguiente").click()
#     driver.refresh()
#
#
# f.close()
#
# ```

# %% [markdown]
# ### Ahora los datos:

# %%
scrap_2013 = pd.read_csv('google_cancer_mama_2013.csv', header = 0, encoding="latin-1")
scrap_2013
# Out:
#                                                 titulo  \
# 0    Investigación genómica contra el cáncer de mam...
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 212                                  Cuerpo | Salud180
# 213  Encuentra el amor con Pokémon Go | ELIMPARCIAL...
# 214  Izúcar de Matamoros - Municipios Puebla | Noti...
# 215                                    Dra. Susan Love
# 216          REB2013 Vol 1 - Facultad de Medicina UNAM
#
#                                                   link           fecha
# 0    http://ciencia.unam.mx/leer/273/Investigacion_...  18 oct. 2013 -
# 1    https://www.cancer.net/es/tipos-de-c%C3%A1ncer...             NaN
# 2    https://www.cdc.gov/spanish/cancer/breast/basi...             NaN
# 3    https://www.unotv.com/nacional/cancer-de-mama-...             NaN
# 4    https://www.cancer.net/es/tipos-de-c%C3%A1ncer...             NaN
# ..                                                 ...             ...
# 212  https://www.salud180.com/salud-dia-a-dia/habit...  27 feb. 2013 -
# 213  https://www.elimparcial.com/sonora/estilos/Enc...  16 ago. 2013 -
# 214  https://m.municipiospuebla.mx/index.php/tags/i...   3 jul. 2013 -
# 215  http://tomateloapecho.org.mx/Pdfs/Seminario%20...  15 ago. 2013 -
# 216  http://www.facmed.unam.mx/publicaciones/ampb/n...  20 jun. 2013 -
#
# [217 rows x 3 columns]

# %% [markdown]
# ### limpio los NAN

# %%
#Eliminar columnas con todos los valores NaN
scrap_2013 = scrap_2013.dropna(axis=0, how='any').reset_index(drop = True)

#cambio de nombres
nombres = {
    ' link':'link',
    ' fecha':'fecha'
}

#cambio los nombres
scrap_2013 = scrap_2013.rename(columns = nombres)
scrap_2013
# Out:
#                                                 titulo  \
# 0    Investigación genómica contra el cáncer de mam...
# 1    Médica Sur apoya la información y diagnóstico ...
# 2                       BOLETÍN CÁNCER DE MAMA - Disur
# 3                       El cáncer de mama - Blog UDLAP
# 4    ¿QUÉ ES EL CÁNCER DE MAMA? - Beneficencia Espa...
# ..                                                 ...
# 208                                  Cuerpo | Salud180
# 209  Encuentra el amor con Pokémon Go | ELIMPARCIAL...
# 210  Izúcar de Matamoros - Municipios Puebla | Noti...
# 211                                    Dra. Susan Love
# 212          REB2013 Vol 1 - Facultad de Medicina UNAM
#
#                                                   link           fecha
# 0    http://ciencia.unam.mx/leer/273/Investigacion_...  18 oct. 2013 -
# 1    http://www.medicasur.com.mx/es_mx/ms/medica-su...   1 oct. 2013 -
# 2    http://www.distribuidoradisur.com.mx/Newslette...  19 oct. 2013 -
# 3    http://blog.udlap.mx/blog/2013/10/sobre-cancer...  18 oct. 2013 -
# 4    https://www.beneficenciaespanola.com.mx/que-es...  26 jul. 2013 -
# ..                                                 ...             ...
# 208  https://www.salud180.com/salud-dia-a-dia/habit...  27 feb. 2013 -
# 209  https://www.elimparcial.com/sonora/estilos/Enc...  16 ago. 2013 -
# 210  https://m.municipiospuebla.mx/index.php/tags/i...   3 jul. 2013 -
# 211  http://tomateloapecho.org.mx/Pdfs/Seminario%20...  15 ago. 2013 -
# 212  http://www.facmed.unam.mx/publicaciones/ampb/n...  20 jun. 2013 -
#
# [213 rows x 3 columns]

# %% [markdown]
# ##### hago un strip de fecha, quiero ver la concentración de publicaciones por mes:

# %%
scrap_2013['mes'] = scrap_2013['fecha'].str.strip().astype(str).str.split(' ', expand = True).iloc[:,1:2]
scrap_2013
# Out:
#                                                 titulo  \
# 0    Investigación genómica contra el cáncer de mam...
# 1    Médica Sur apoya la información y diagnóstico ...
# 2                       BOLETÍN CÁNCER DE MAMA - Disur
# 3                       El cáncer de mama - Blog UDLAP
# 4    ¿QUÉ ES EL CÁNCER DE MAMA? - Beneficencia Espa...
# ..                                                 ...
# 208                                  Cuerpo | Salud180
# 209  Encuentra el amor con Pokémon Go | ELIMPARCIAL...
# 210  Izúcar de Matamoros - Municipios Puebla | Noti...
# 211                                    Dra. Susan Love
# 212          REB2013 Vol 1 - Facultad de Medicina UNAM
#
#                                                   link           fecha   mes
# 0    http://ciencia.unam.mx/leer/273/Investigacion_...  18 oct. 2013 -  oct.
# 1    http://www.medicasur.com.mx/es_mx/ms/medica-su...   1 oct. 2013 -  oct.
# 2    http://www.distribuidoradisur.com.mx/Newslette...  19 oct. 2013 -  oct.
# 3    http://blog.udlap.mx/blog/2013/10/sobre-cancer...  18 oct. 2013 -  oct.
# 4    https://www.beneficenciaespanola.com.mx/que-es...  26 jul. 2013 -  jul.
# ..                                                 ...             ...   ...
# 208  https://www.salud180.com/salud-dia-a-dia/habit...  27 feb. 2013 -  feb.
# 209  https://www.elimparcial.com/sonora/estilos/Enc...  16 ago. 2013 -  ago.
# 210  https://m.municipiospuebla.mx/index.php/tags/i...   3 jul. 2013 -  jul.
# 211  http://tomateloapecho.org.mx/Pdfs/Seminario%20...  15 ago. 2013 -  ago.
# 212  http://www.facmed.unam.mx/publicaciones/ampb/n...  20 jun. 2013 -  jun.
#
# [213 rows x 4 columns]

# %% [markdown]
# ### ahora agrupo por mes:

# %%
#me doy cuenta de que hay cosas coladas...

scrap_2013["mes"].unique()
# Out:
# array(['oct.', 'jul.', 'L', 'feb.', 'nov.', 'sep.', 'N', 'MA', 'abr.',
#        'jun.', 'dic.', 'R', 'M', 'ago.', 'ÁN', 'P', 'may.', 'JM', 'LL',
#        'ene.', 'C', 'mar.', 'J', 'JEA', 'Á', 'LAS', 'MLM', 'ZC', 'MPM',
#        'A', 'JA', 'YL', 'KEF', 'G', 'O', 'CH', 'AL', 'SA', 'LJ', 'HDG',
#        'PJ', 'CI'], dtype=object)

# %%
#remapeo para eliminar mediante NA: 

meses = {
    'ene.':'enero',
    'feb.':'febrero',
    'mar.':'marzo',
    'abr.':'abril',
    'may.': 'mayo', 
    'jun.': 'junio',
    'jul.': 'julio',
    'ago.': 'agosto',
    'sep.': 'septiembre',
    'oct.': 'octubre',
    'nov.': 'noviembre',
    'dic.':'diciembre'
}

scrap_2013['meses'] = scrap_2013['mes'].map(meses)

# %%
#ahora elimino las columnas que no traían el mes, posteriormente reemplazadas por NaN
scrap_2013 = scrap_2013.dropna(axis=0, how='any').reset_index(drop = True)

# %%
scrap_2013
# Out:
#                                                 titulo  \
# 0    Investigación genómica contra el cáncer de mam...
# 1    Médica Sur apoya la información y diagnóstico ...
# 2                       BOLETÍN CÁNCER DE MAMA - Disur
# 3                       El cáncer de mama - Blog UDLAP
# 4    ¿QUÉ ES EL CÁNCER DE MAMA? - Beneficencia Espa...
# ..                                                 ...
# 164                                  Cuerpo | Salud180
# 165  Encuentra el amor con Pokémon Go | ELIMPARCIAL...
# 166  Izúcar de Matamoros - Municipios Puebla | Noti...
# 167                                    Dra. Susan Love
# 168          REB2013 Vol 1 - Facultad de Medicina UNAM
#
#                                                   link           fecha   mes  \
# 0    http://ciencia.unam.mx/leer/273/Investigacion_...  18 oct. 2013 -  oct.
# 1    http://www.medicasur.com.mx/es_mx/ms/medica-su...   1 oct. 2013 -  oct.
# 2    http://www.distribuidoradisur.com.mx/Newslette...  19 oct. 2013 -  oct.
# 3    http://blog.udlap.mx/blog/2013/10/sobre-cancer...  18 oct. 2013 -  oct.
# 4    https://www.beneficenciaespanola.com.mx/que-es...  26 jul. 2013 -  jul.
# ..                                                 ...             ...   ...
# 164  https://www.salud180.com/salud-dia-a-dia/habit...  27 feb. 2013 -  feb.
# 165  https://www.elimparcial.com/sonora/estilos/Enc...  16 ago. 2013 -  ago.
# 166  https://m.municipiospuebla.mx/index.php/tags/i...   3 jul. 2013 -  jul.
# 167  http://tomateloapecho.org.mx/Pdfs/Seminario%20...  15 ago. 2013 -  ago.
# 168  http://www.facmed.unam.mx/publicaciones/ampb/n...  20 jun. 2013 -  jun.
#
#        meses
# 0    octubre
# 1    octubre
# 2    octubre
# 3    octubre
# 4      julio
# ..       ...
# 164  febrero
# 165   agosto
# 166    julio
# 167   agosto
# 168    junio
#
# [169 rows x 5 columns]

# %% [markdown]
# #### Ahora vuelvo a agrupar por mes:

# %%
scrap_2013.groupby(["mes"])['mes'].agg("count")
# Out:
# mes
# abr.     5
# ago.     8
# dic.    12
# ene.     4
# feb.     9
# jul.     9
# jun.     9
# mar.     4
# may.    15
# nov.    16
# oct.    68
# sep.    10
# Name: mes, dtype: int64

# %% [markdown]
# ### De aquí podemos ver de manera inmediata la diferencia de atención que se le da al problema, con respecto a otros meses.

# %% [markdown]
# ### Analogamente para las demás:

# %%
scrap_2014 = pd.read_csv('google_cancer_mama_2014.csv', header = 0, encoding="latin-1")
#Eliminar columnas con todos los valores NaN
scrap_2014 = scrap_2014.dropna(axis=0, how='any').reset_index(drop = True)

#cambio los nombres:
scrap_2014 = scrap_2014.rename(columns = nombres)
scrap_2014['mes'] = scrap_2014['fecha'].str.strip().astype(str).str.split(' ', expand = True).iloc[:,1:2]

#quito las entradas coladas:
scrap_2014['meses'] = scrap_2014['mes'].map(meses)
#ahora elimino las columnas que no traían el mes, posteriormente reemplazadas por NaN
scrap_2014 = scrap_2014.dropna(axis=0, how='any').reset_index(drop = True)
#finalmente agrupo por mes:
scrap_2014.groupby(["mes"])['mes'].agg("count")
# Out:
# mes
# abr.     6
# ago.     8
# dic.    10
# ene.    11
# feb.    10
# jul.     9
# jun.    19
# mar.    14
# may.    15
# nov.    17
# oct.    82
# sep.    19
# Name: mes, dtype: int64

# %%
scrap_2015 = pd.read_csv('google_cancer_mama_2015.csv', header = 0, encoding="latin-1")
#Eliminar columnas con todos los valores NaN
scrap_2015 = scrap_2015.dropna(axis=0, how='any').reset_index(drop = True)

#cambio los nombres:
scrap_2015 = scrap_2015.rename(columns = nombres)
scrap_2015['mes'] = scrap_2015['fecha'].str.strip().astype(str).str.split(' ', expand = True).iloc[:,1:2]

#quito las entradas coladas:
scrap_2015['meses'] = scrap_2015['mes'].map(meses)
#ahora elimino las columnas que no traían el mes, posteriormente reemplazadas por NaN
scrap_2015 = scrap_2015.dropna(axis=0, how='any').reset_index(drop = True)
#finalmente agrupo por mes:
scrap_2015.groupby(["mes"])['mes'].agg("count")
# Out:
# mes
# abr.      7
# ago.     10
# dic.     16
# ene.     22
# feb.     12
# jul.     10
# jun.     10
# mar.     17
# may.      7
# nov.     25
# oct.    130
# sep.     31
# Name: mes, dtype: int64

# %%
scrap_2016 = pd.read_csv('google_cancer_mama_2016.csv', header = 0, encoding="latin-1")
#Eliminar columnas con todos los valores NaN
scrap_2016 = scrap_2016.dropna(axis=0, how='any').reset_index(drop = True)

#cambio los nombres:
scrap_2016 = scrap_2016.rename(columns = nombres)
scrap_2016['mes'] = scrap_2016['fecha'].str.strip().astype(str).str.split(' ', expand = True).iloc[:,1:2]

#quito las entradas coladas:
scrap_2016['meses'] = scrap_2016['mes'].map(meses)
#ahora elimino las columnas que no traían el mes, posteriormente reemplazadas por NaN
scrap_2016 = scrap_2016.dropna(axis=0, how='any').reset_index(drop = True)
#finalmente agrupo por mes:
scrap_2016.groupby(["mes"])['mes'].agg("count")
# Out:
# mes
# abr.      9
# ago.     11
# dic.     15
# ene.     22
# feb.     11
# jul.      9
# jun.      6
# mar.      8
# may.     15
# nov.     16
# oct.    112
# sep.     23
# Name: mes, dtype: int64

# %%
scrap_2017 = pd.read_csv('google_cancer_mama_2017.csv', header = 0, encoding="latin-1")
#Eliminar columnas con todos los valores NaN
scrap_2017 = scrap_2017.dropna(axis=0, how='any').reset_index(drop = True)

#cambio los nombres:
scrap_2017 = scrap_2017.rename(columns = nombres)
scrap_2017['mes'] = scrap_2017['fecha'].str.strip().astype(str).str.split(' ', expand = True).iloc[:,1:2]

#quito las entradas coladas:
scrap_2017['meses'] = scrap_2017['mes'].map(meses)
#ahora elimino las columnas que no traían el mes, posteriormente reemplazadas por NaN
scrap_2017 = scrap_2017.dropna(axis=0, how='any').reset_index(drop = True)
#finalmente agrupo por mes:
scrap_2017.groupby(["mes"])['mes'].agg("count")
# Out:
# mes
# abr.     11
# ago.     16
# dic.     15
# ene.      2
# feb.     19
# jul.     10
# jun.     18
# mar.     13
# may.     12
# nov.     11
# oct.    143
# sep.     16
# Name: mes, dtype: int64

# %%
scrap_2018 = pd.read_csv('google_cancer_mama_2018.csv', header = 0, encoding="latin-1")
#Eliminar columnas con todos los valores NaN
scrap_2018 = scrap_2018.dropna(axis=0, how='any').reset_index(drop = True)

#cambio los nombres:
scrap_2018 = scrap_2018.rename(columns = nombres)
scrap_2018['mes'] = scrap_2018['fecha'].str.strip().astype(str).str.split(' ', expand = True).iloc[:,1:2]

#quito las entradas coladas:
scrap_2018['meses'] = scrap_2018['mes'].map(meses)
#ahora elimino las columnas que no traían el mes, posteriormente reemplazadas por NaN
scrap_2018 = scrap_2018.dropna(axis=0, how='any').reset_index(drop = True)
#finalmente agrupo por mes:
scrap_2018.groupby(["mes"])['mes'].agg("count")
# Out:
# mes
# abr.     20
# ago.     13
# dic.      7
# ene.      4
# feb.     11
# jul.      9
# jun.     12
# mar.     13
# may.      6
# nov.     18
# oct.    140
# sep.     13
# Name: mes, dtype: int64

# %%
scrap_2019 = pd.read_csv('google_cancer_mama_2019.csv', header = 0, encoding="latin-1")
#Eliminar columnas con todos los valores NaN
scrap_2019 = scrap_2019.dropna(axis=0, how='any').reset_index(drop = True)

#cambio los nombres:
scrap_2019 = scrap_2019.rename(columns = nombres)
scrap_2019['mes'] = scrap_2019['fecha'].str.strip().astype(str).str.split(' ', expand = True).iloc[:,1:2]

#quito las entradas coladas:
scrap_2019['meses'] = scrap_2019['mes'].map(meses)
#ahora elimino las columnas que no traían el mes, posteriormente reemplazadas por NaN
scrap_2019 = scrap_2019.dropna(axis=0, how='any').reset_index(drop = True)
#finalmente agrupo por mes:
scrap_2019.groupby(["mes"])['mes'].agg("count")
# Out:
# mes
# abr.     15
# ago.     11
# dic.      7
# ene.      8
# feb.     33
# jul.     16
# jun.     13
# mar.     13
# may.      3
# nov.     27
# oct.    157
# sep.     13
# Name: mes, dtype: int64

# %% [markdown]
# ### De la observación de los DF obtenidos mediante web scrapping podemos afirmar que: 1. el problema de divulgación acerca de cáncer de mama está focalizado de manera casi única al mes de octubre y 2. que si bien es cierto que el índice atención que le han brindado los medios de comunicación, como lo son los medios digitales que analizamos en este caso ha aumentado, no ha tenido suficiente impacto como para hacer que el índice de morbilidad caiga, por lo que se afirma que México no está consciente del problema de salud que implica el cáncer de mama.
